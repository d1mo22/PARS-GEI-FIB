# %% [markdown]
# # CAIM Lab Session 1: Powerlaws

# %% [markdown]
# In this session you will:
#
# - Do simple preprocessing with `nltk`
# - Learn about power laws, a special case being Zipf's law
# - Investigate whether _Don Quijote_ follows Zipf and Herden's power laws

# %%
# uncomment in case you need to install nltk
# !pip install nltk--user

# %% [markdown]
# ## 1. On preprocessing (with `nltk`)
#
# For this first project, you may use the very popular [natural language tooklit library](https://www.nltk.org) which provides useful language processing functionality.
#
# In what follows you can see some examples of the type of preprocessing that we will use during the course.
#
# - _Tokenization:_ is the process that splits a sequence of characters into a sequence of word types (or _tokens_)
#
# - _Lower case folding_: turning all characters to lowercase
#
# - _Stopword removal:_ removes tokens that correspond to functional words (or _stopwords_)
#
# - _Stemming:_ mapping word types to their stem (normalization)

# %%
from pprint import pprint

import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')

# %%
## tokenizer

from nltk.tokenize import word_tokenize

text = """Primera parte del ingenioso hidalgo don Quijote de la Mancha.
  Capitulo primero. Que trata de la condicion y ejercicio del famoso hidalgo
  don Quijote de la Mancha"""

tokenized_text = word_tokenize(text)

pprint(tokenized_text)
# Out:
# ['Primera',
#  'parte',
#  'del',
#  'ingenioso',
#  'hidalgo',
#  'don',
#  'Quijote',
#  'de',
#  'la',
#  'Mancha',
#  '.',
#  'Capitulo',
#  'primero',
#  '.',
#  'Que',
#  'trata',
#  'de',
#  'la',
#  'condicion',
#  'y',
#  'ejercicio',
#  'del',
#  'famoso',
#  'hidalgo',
#  'don',
#  'Quijote',
#  'de',
#  'la',
#  'Mancha']

# %%
## stopword removal, punctuation removal, lower-case folding

from nltk.corpus import stopwords
import string

spanish_sw = set(stopwords.words('spanish') + list(string.punctuation))

print(f'there are {len(spanish_sw)} stopwords in Spanish (including punctuation), which are: {spanish_sw}')

filtered_tokenized_text = [w.lower() for w in tokenized_text if w.lower() not in spanish_sw]
pprint(filtered_tokenized_text)
# Out:
# there are 345 stopwords in Spanish (including punctuation), which are: {'*', 'tú', 'donde', 'hubimos', 'haya', 'tuvisteis', 'fuese', 'o', 'estabais', 'tiene', 'tuvierais', 'teniendo', 'hubieron', 'habidos', 'pero', 'habríamos', 'hay', 'estarás', 'sentidos', '!', 'tendrán', '}', 'teníais', 'fui', 'estuviste', 'son', 'habida', 'estuvieron', 'y', 'seáis', 'estuvieras', 'estuve', 'también', 'mías', 'más', '{', 'tuvieran', 'somos', 'tuvieses', 'tuyo', 'estad', 'su', 'sin', '$', 'estos', 'hubiesen', 'fuesen', 'el', 'este', 'hasta', 'tuyas', "'", 'vosotras', 'eran', 'desde', 'estaba', 'seríais', 'muchos', 'tuviese', 'ya', 'hubieran', 'suyas', 'tendría', 'antes', 'tendríais', 'ese', 'tendrían', 'mí', 'vuestra', 'le', 'tengo', 'tendremos', 'tenía', 'entre', 'tenéis', '_', 'ellas', 'nuestras', 'serán', 'sentida', 'tuviéramos', 'poco', 'estáis', 'eso', 'otras', 'habréis', 'tenías', 'esta', 'estuvo', 'siente', 'sus', 'habrás', 'sobre', 'estemos', 'hubiera', 'tuviésemos', 'seré', 'otra', 'tuvieron', 'fuerais', 'fuera', 'habría', 'tened', 'estadas', 'todo', 'vuestro', 'esas', 'estado', 'seas', 'estar', 'ni', 'hubiste', 'sentido', 'éramos', 'tuve', '-', 'fuiste', 'has', 'tenidas', 'estuvimos', 'les', 'fue', 'esos', 'estabas', 'estaríamos', 'han', 'estuvieses', '`', 'estaréis', 'hubiésemos', 'estén', 'tuviesen', 'tendríamos', 'estas', 'hayáis', 'estados', 'los', 'míos', 'era', 'están', 'tuvo', 'estuvierais', 'hubierais', 'otros', 'estará', 'estuvieran', 'tanto', 'hube', 'estés', 'hubiese', 'porque', 'estarías', '[', 'él', 'estaban', 'ellos', 'fuéramos', 'es', 'tuvieseis', 'un', 'las', 'tendrías', 'fueron', 'hubieras', '%', 'habríais', 'e', '|', 'estuvisteis', 'al', 'hayamos', 'seamos', 'esté', 'tuya', 'estarían', 'hubieses', '+', 'estéis', 'erais', 'en', 'cual', 'estaríais', 'tenidos', 'nuestra', 'tenido', 'nosotros', 'sería', 'hayas', 'que', 'tendré', 'tienes', 'estuviéramos', '#', 'se', 'estuvieseis', 'como', 'seremos', 'tengas', '^', 'suyos', 'estaría', '=', 'nos', 'fuésemos', 'serían', 'tendrá', 'de', 'me', 'serías', 'tuviera', '~', 'fueseis', '<', 'habías', 'habidas', '&', 'cuando', 'estábamos', 'tengáis', '>', 'habiendo', 'suyo', '.', 'te', 'otro', 'soy', 'tuvimos', 'a', 'estuviésemos', 'nada', 'mucho', ';', 'será', 'del', 'habéis', 'quien', 'fuisteis', 'sintiendo', 'algo', 'sí', 'tengan', 'tuvieras', 'mis', 'habrá', 'fueses', ']', 'habrías', 'tendrás', 'hubiéramos', 'unos', '?', 'hemos', 'tenemos', 'estamos', 'fueras', 'una', 'eres', 'ha', 'hubo', 'sentidas', 'vuestras', 'estarán', 'fuimos', 'suya', 'todos', 'ella', 'tenga', 'uno', 'he', 'os', 'habían', 'con', 'estuviesen', 'por', 'ti', 'sea', 'tenían', 'estás', 'no', 'quienes', 'estaremos', 'qué', '(', 'tengamos', 'contra', 'nuestro', 'nuestros', ':', 'hayan', 'fueran', 'habrán', '\\', 'vosotros', 'estuviera', 'habíais', 'esa', 'estada', 'eras', 'sentid', 'ante', ')', 'vuestros', 'tu', 'habremos', 'hubieseis', 'hubisteis', 'tuviste', 'mía', 'habíamos', 'la', 'habré', 'esto', '"', 'algunas', 'estando', 'para', 'tus', 'mío', 'sois', 'mi', 'durante', 'teníamos', 'estuviese', 'serás', 'tuyos', 'tienen', 'seríamos', 'está', 'seréis', 'lo', 'estoy', 'habido', 'tenida', 'muy', 'sean', 'estaré', 'había', 'algunos', 'yo', 'nosotras', 'habrían', '@', ',', '/', 'tendréis'}
# ['primera',
#  'parte',
#  'ingenioso',
#  'hidalgo',
#  'don',
#  'quijote',
#  'mancha',
#  'capitulo',
#  'primero',
#  'trata',
#  'condicion',
#  'ejercicio',
#  'famoso',
#  'hidalgo',
#  'don',
#  'quijote',
#  'mancha']

# %%
## stemmer

from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer('spanish')

stemmed_text = [stemmer.stem(w) for w in filtered_tokenized_text]
pprint(stemmed_text)
# Out:
# ['primer',
#  'part',
#  'ingeni',
#  'hidalg',
#  'don',
#  'quijot',
#  'manch',
#  'capitul',
#  'primer',
#  'trat',
#  'condicion',
#  'ejercici',
#  'famos',
#  'hidalg',
#  'don',
#  'quijot',
#  'manch']

# %%
## useful for counting words

from collections import Counter

word_counts = Counter(stemmed_text)
pprint(word_counts)

word_counts_no_stem = Counter(filtered_tokenized_text)
pprint(word_counts_no_stem)
# Out:
# Counter({'primer': 2,
#          'hidalg': 2,
#          'don': 2,
#          'quijot': 2,
#          'manch': 2,
#          'part': 1,
#          'ingeni': 1,
#          'capitul': 1,
#          'trat': 1,
#          'condicion': 1,
#          'ejercici': 1,
#          'famos': 1})
# Counter({'hidalgo': 2,
#          'don': 2,
#          'quijote': 2,
#          'mancha': 2,
#          'primera': 1,
#          'parte': 1,
#          'ingenioso': 1,
#          'capitulo': 1,
#          'primero': 1,
#          'trata': 1,
#          'condicion': 1,
#          'ejercicio': 1,
#          'famoso': 1})

# %% [markdown]
# ## 2. On powerlaws
#
# Consider a function $y=f(x)$, that we will call a "law" relating $y$ with $x$.
#
# __Example 1.__ You are given a bucket of some radioactive isotope. $x$ is the number of seconds since you were given
# the bucket. $y$ is the number of atoms that disintegrate at the $x$th second.
# Each atom decides independently from all other atoms whether to disintegrate in the next second (or
# nanosecond, or whatever). From here you can see that $f$ will have the form $y=c \cdot x^{-a}$,
# where $c$ depends on the number of atoms you were given, and $a$ depends on the isotope. In particular,
# $a>1$ determines the half-life of the isotope.
#
# __Example 2.__ $x$ is number of seconds and $y$ is the number of people entering a metro station during the next
# 10 minutes. You may have been told in statistics that $f$ is given by the Poisson distribution
# (at least for ideal people and metro stations).
#
# Many natural and artificial phenomena come in distributions that are neither exponential nor Poisson,
# but so-called power laws. Intuitively, we have $y$ evolves like $x^a$, where $a$ is a constant called
# the _exponent_ of the power law. If $a$ is positive, $y$ is increasing, and if $a$ is negative,
# $y$ decreases.
#
# More precisely, a power law is
# $$
# y = c \cdot (x+b)^a
# $$
# for three constants $a$, $b$, and $c$.
#
# There is a lot of theory about why powerlaws are ubiqutous. They are often related to self-organization,
# fractality, complex dynamical systems, etc. The Web and social networks are full of powerlaws.
# So is human language, social sciences (population of cities), and natural sciences (intensity of earthquakes,
# relation of size and metabolism in animals).
#
# A powerlaw with exponent $-1$ is called Zipf's law, after Mr. Zipf. By extension, sometimes powerlaws with
# negative exponents are also called Zipfian laws.
#
# In what follows we will fit some datasets to the best powerlaw that we can find - and see that they pretty close.
# Note that this does NOT mean that the phenomenon generating the dataset is exactly a powerlaw.
# Proving seriously that a law is (or is not) a powerlaw is another matter.

# %% [markdown]
# ## 3. Looking at "Don Quijote"
#
# In this exercise, we will be looking at Zipf's and Heap's text laws of the classical text _Don Quijote_. The full plain text is publicly available in many places. You should do a basic preprocessing before counting words. For this exercise, it is better if you _do not remove stopwords_ since we are trying to reflect the full word frequency distribution, including stopwords.

# %%
# load don quijote, e.g. as in:

import urllib.request

target_url = "https://fegalaz.usc.es/~gamallo/aulas/lingcomputacional/corpus/quijote-es.txt"

data = urllib.request.urlopen(target_url)

# print first N lines only as a demo
N = 10
for _ in range(N):
    line = next(data)
    print(line.decode('latin-1').strip())
# Out:
# Primera parte del ingenioso hidalgo don Quijote de la Mancha
# Capítulo primero. Que trata de la condición y ejercicio del famoso hidalgo
# don Quijote de la Mancha
# En un lugar de la Mancha, de cuyo nombre no quiero acordarme, no ha mucho
# tiempo que vivía un hidalgo de los de lanza en astillero, adarga antigua,
# rocín flaco y galgo corredor. Una olla de algo más vaca que carnero,
# salpicón las más noches, duelos y quebrantos los sábados, lantejas los
# viernes, algún palomino de añadidura los domingos, consumían las tres
# partes de su hacienda. El resto della concluían sayo de velarte, calzas de
# velludo para las fiestas, con sus pantuflos de lo mesmo, y los días de

# %% [markdown]
# ---
#
# __Exercise 1.__ Use `python` + `matplotlib` or similar library to plot the frequence of words in `don quijote` in decreasing order.
#
# ---
#
# Is it a powerlaw? Or, can it be approximated by a powerlaw?
#
# A trick about powerlaws is the following. Let's forget about the $b$ parameter for a second (or equivalently assume that $b = 0$),
# so our powerlaw looks like
# $$
# y = c \cdot x^a.
# $$
#
# Taking logs on both sides, it becomes
# $$
# \log y = a \cdot \log x + \log c
# $$
#
# I.e., $\log y$ is a linear function of $\log x$.
#
# ---

# %%
# Contar las palabras y ordenarlas en orden decreciente (hacer un grafico para poder ver los resultados) hacer una regresion lineal
# para encontrar el exponente de la pendiente
from nltk.tokenize import word_tokenize
import matplotlib as mpl
import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from collections import Counter
import string
import urllib.request

target_url = "https://fegalaz.usc.es/~gamallo/aulas/lingcomputacional/corpus/quijote-es.txt"

data = urllib.request.urlopen(target_url)

# Primero tokenizamos el texto
text = data.read().decode('latin-1')
text = text.replace("-"," ").replace("¿"," ").replace("¡"," ")

tokenized_text = word_tokenize(text)

# Luego filtramos el texto para poner todas las palabras en minuscula
spanish_sw = set(list(string.punctuation))
filtered_tokenized_text = [w.lower() for w in tokenized_text if w not in spanish_sw]

word_counts = Counter(filtered_tokenized_text)

pprint(word_counts)
pprint(len(word_counts))

# Obtener las palabras y sus frecuencias ordenadas de mayor a menor
most_common = word_counts.most_common(500) 

position = list(range(len(most_common)))
counts = [count for word, count in most_common]
    
# Realizamos el grafico con las 200 palabras mas repetidas 
plt.figure(figsize=(24, 12))
plt.plot(range(500), counts)
plt.xticks(rotation=45, ha="right")
plt.xlabel('Palabras (ordenadas por frecuencia)')
plt.ylabel('Frecuencia')
plt.title('Frecuencia de las 500 palabras más comunes en Don Quijote')
plt.tight_layout()
plt.show()
# Out:
# Counter({'que': 20414,
#          'y': 17982,
#          'de': 17952,
#          'la': 10227,
#          'a': 9718,
#          'en': 8110,
#          'el': 8076,
#          'no': 6275,
#          'los': 4701,
#          'se': 4644,
#          'con': 4170,
#          'por': 3883,
#          'las': 3427,
#          'lo': 3416,
#          'le': 3380,
#          'su': 3334,
#          'don': 2628,
#          'del': 2452,
#          'me': 2325,
#          'como': 2242,
#          'quijote': 2156,
#          'sancho': 2142,
#          'es': 2124,
#          'yo': 2061,
#          'más': 2020,
#          'si': 1938,
#          'un': 1910,
#          'dijo': 1804,
#          'al': 1701,
#          'mi': 1686,
#          'para': 1435,
#          'porque': 1385,
#          'ni': 1348,
#          'una': 1318,
#          'él': 1270,
#          'tan': 1220,
#          'o': 1190,
#          'todo': 1169,
#          'sin': 1142,
#          'respondió': 1063,
#          'así': 1059,
#          'ser': 1054,
#          'señor': 1054,
#          'ha': 1046,
#          'bien': 1041,
#          'sus': 1038,
#          'había': 1032,
#          'pero': 1010,
#          'merced': 898,
#          'esto': 877,
#          'pues': 855,
#          'vuestra': 838,
#          'qué': 835,
#          'todos': 811,
#          'ya': 782,
#          'era': 753,
#          'cuando': 750,
#          'te': 709,
#          'cual': 691,
#          'sino': 688,
#          'dos': 681,
#          'donde': 668,
#          'caballero': 655,
#          'fue': 640,
#          'este': 635,
#          'esta': 615,
#          'quien': 603,
#          'ella': 597,
#          'decir': 574,
#          'muy': 532,
#          'he': 531,
#          'hacer': 526,
#          'dios': 525,
#          'aunque': 523,
#          'señora': 515,
#          'aquí': 514,
#          'otra': 508,
#          'otro': 507,
#          'mí': 497,
#          'aquel': 484,
#          'son': 480,
#          'estaba': 478,
#          'hay': 466,
#          'mal': 453,
#          'sobre': 451,
#          'nos': 445,
#          'cosa': 442,
#          'os': 437,
#          'buen': 437,
#          'está': 436,
#          'verdad': 429,
#          'tal': 422,
#          'allí': 421,
#          'tanto': 417,
#          'ver': 405,
#          'tengo': 401,
#          'mundo': 389,
#          'luego': 386,
#          'mis': 386,
#          'hasta': 383,
#          'sé': 382,
#          'alguna': 381,
#          'tiene': 378,
#          'poco': 376,
#          'entre': 372,
#          'todas': 368,
#          'dar': 364,
#          'ahora': 364,
#          'dicho': 360,
#          'buena': 359,
#          'parte': 357,
#          'vida': 355,
#          'tenía': 349,
#          'uno': 349,
#          'han': 347,
#          'les': 346,
#          'sí': 345,
#          'cosas': 345,
#          'lugar': 343,
#          'menos': 339,
#          'eso': 335,
#          'gran': 334,
#          'aquella': 333,
#          'casa': 332,
#          'soy': 331,
#          "''": 329,
#          'manera': 324,
#          'panza': 324,
#          'digo': 322,
#          'tiempo': 321,
#          'tu': 321,
#          'toda': 314,
#          'cura': 313,
#          'puesto': 304,
#          'mano': 301,
#          'ellos': 294,
#          'amo': 294,
#          'dio': 293,
#          'caballeros': 293,
#          'mucho': 292,
#          'mejor': 292,
#          'antes': 289,
#          '»': 287,
#          'fuera': 285,
#          'puede': 283,
#          'sea': 281,
#          'visto': 281,
#          'algún': 280,
#          'ojos': 280,
#          'dulcinea': 277,
#          'tierra': 271,
#          'día': 271,
#          'otras': 271,
#          'hecho': 270,
#          'cómo': 269,
#          'quién': 267,
#          'otros': 260,
#          'tú': 259,
#          'quiero': 258,
#          'aun': 258,
#          'hombre': 256,
#          'padre': 256,
#          'haber': 252,
#          'habían': 251,
#          'cielo': 249,
#          'vio': 245,
#          'camino': 245,
#          'parece': 245,
#          'saber': 244,
#          'estas': 243,
#          'hizo': 243,
#          'amigo': 242,
#          'muchas': 240,
#          'tener': 239,
#          'historia': 239,
#          'días': 238,
#          'manos': 237,
#          'escudero': 237,
#          'mas': 235,
#          'cuanto': 234,
#          'también': 232,
#          'tres': 231,
#          'desta': 231,
#          'fin': 228,
#          'mujer': 226,
#          'dice': 224,
#          'será': 219,
#          'mesmo': 216,
#          'cabeza': 215,
#          'cada': 215,
#          'noche': 211,
#          'cuenta': 210,
#          'punto': 209,
#          'replicó': 208,
#          'fuese': 206,
#          'veces': 205,
#          'nuestro': 204,
#          'vuesa': 202,
#          'rocinante': 200,
#          'parecer': 200,
#          'razones': 199,
#          'duque': 199,
#          'estos': 198,
#          'muchos': 198,
#          'diciendo': 198,
#          'caballo': 197,
#          'después': 195,
#          'debe': 195,
#          'andante': 194,
#          'vos': 194,
#          'gusto': 193,
#          'sólo': 193,
#          'pie': 193,
#          'podía': 193,
#          'grande': 193,
#          'eran': 191,
#          'vez': 189,
#          'duquesa': 189,
#          'decía': 188,
#          'primero': 187,
#          'llegó': 185,
#          '``': 185,
#          'mío': 185,
#          'oh': 183,
#          'mil': 183,
#          'mucha': 180,
#          'voz': 179,
#          'duda': 177,
#          'adelante': 176,
#          'nombre': 175,
#          'estaban': 175,
#          'mismo': 175,
#          'gobernador': 174,
#          'barbero': 167,
#          'modo': 167,
#          'desde': 167,
#          'mancha': 162,
#          'según': 162,
#          'andantes': 162,
#          'estar': 162,
#          'dado': 162,
#          'nada': 162,
#          'hija': 162,
#          'sido': 161,
#          'iba': 161,
#          'toboso': 161,
#          'voluntad': 160,
#          'deseo': 158,
#          'quiso': 158,
#          'cuatro': 157,
#          'aquellos': 156,
#          'gente': 156,
#          'armas': 155,
#          'vuestro': 154,
#          'has': 154,
#          'capítulo': 152,
#          'rostro': 152,
#          'ventura': 152,
#          'tales': 152,
#          'hace': 151,
#          'alma': 151,
#          'viendo': 151,
#          'venía': 151,
#          'entender': 150,
#          'razón': 150,
#          'nunca': 150,
#          'señores': 150,
#          'tanta': 149,
#          'muerte': 149,
#          'deste': 148,
#          'siempre': 148,
#          'menester': 148,
#          'va': 148,
#          'fueron': 148,
#          'camila': 148,
#          'palabra': 147,
#          'doncella': 147,
#          'agora': 147,
#          'cuerpo': 146,
#          'entonces': 144,
#          'quiere': 144,
#          'cuales': 143,
#          'mía': 143,
#          'nadie': 142,
#          'caballería': 142,
#          'puso': 142,
#          'tienen': 142,
#          'lotario': 142,
#          'suelo': 141,
#          'castillo': 140,
#          'corazón': 140,
#          'dicen': 140,
#          'venta': 140,
#          'ninguna': 140,
#          'alguno': 139,
#          'jamás': 139,
#          'suerte': 139,
#          'ir': 139,
#          'hermosa': 139,
#          'nuestra': 138,
#          'anselmo': 138,
#          'libros': 137,
#          'vino': 137,
#          'preguntó': 137,
#          'fernando': 135,
#          'pies': 134,
#          'finalmente': 133,
#          'quedó': 132,
#          'persona': 132,
#          'comenzó': 132,
#          'unos': 132,
#          'mala': 132,
#          'voces': 132,
#          'mayor': 131,
#          'años': 129,
#          'caso': 129,
#          'dél': 129,
#          'rey': 129,
#          'tus': 129,
#          'aventura': 128,
#          'salir': 128,
#          'fuerza': 128,
#          'éste': 128,
#          'algo': 127,
#          'grandes': 126,
#          'poner': 126,
#          'memoria': 126,
#          'ellas': 126,
#          'oído': 126,
#          'mitad': 125,
#          'contra': 125,
#          'delante': 124,
#          'tuvo': 123,
#          'palabras': 123,
#          'hermosura': 123,
#          'causa': 122,
#          'cierto': 122,
#          'fama': 121,
#          'amor': 121,
#          'volvió': 121,
#          'posible': 121,
#          'algunos': 119,
#          'sabe': 119,
#          'rucio': 119,
#          'contento': 118,
#          'ventero': 118,
#          'demás': 117,
#          'ínsula': 116,
#          'hacía': 116,
#          'sería': 116,
#          'pasar': 115,
#          'ese': 115,
#          'venir': 114,
#          'haya': 114,
#          'están': 114,
#          'casi': 113,
#          'figura': 113,
#          'gobierno': 113,
#          'nuevo': 112,
#          'debía': 112,
#          'ello': 111,
#          'espada': 111,
#          'loco': 111,
#          'dejar': 111,
#          'nosotros': 111,
#          'dorotea': 111,
#          'bueno': 109,
#          'tantas': 109,
#          'bachiller': 109,
#          'siendo': 108,
#          'junto': 108,
#          'hora': 108,
#          'muerto': 107,
#          'habéis': 107,
#          'volver': 107,
#          'daba': 106,
#          'da': 106,
#          'boca': 106,
#          'tomar': 105,
#          'hermano': 105,
#          'intención': 105,
#          'pena': 105,
#          'triste': 105,
#          'pueblo': 104,
#          'aquello': 104,
#          'buscar': 104,
#          'ocasión': 104,
#          'apenas': 104,
#          'pedro': 103,
#          'partes': 102,
#          'della': 101,
#          'unas': 101,
#          'estoy': 101,
#          'buenos': 101,
#          'hombres': 101,
#          'ciudad': 101,
#          'cardenio': 101,
#          'pensamientos': 100,
#          'pareció': 100,
#          'llevar': 100,
#          'poder': 100,
#          'lengua': 100,
#          'pudo': 99,
#          'estado': 99,
#          'comer': 99,
#          'paso': 99,
#          'luscinda': 99,
#          'ninguno': 98,
#          'medio': 98,
#          'lágrimas': 98,
#          'solo': 97,
#          'adonde': 97,
#          'tantos': 97,
#          'pienso': 97,
#          'esa': 97,
#          'dellos': 96,
#          'pobre': 96,
#          'hijo': 96,
#          'quería': 96,
#          'hablar': 96,
#          'creo': 96,
#          'vista': 96,
#          'puedo': 96,
#          'carta': 96,
#          'aquellas': 95,
#          'parecía': 95,
#          'libro': 94,
#          'orden': 94,
#          'traía': 94,
#          'oro': 93,
#          'hubo': 93,
#          'viene': 93,
#          'diablo': 93,
#          'aposento': 93,
#          'primera': 92,
#          'aventuras': 92,
#          'ésta': 92,
#          'podría': 92,
#          'buenas': 92,
#          'brazos': 91,
#          'suyo': 91,
#          'estando': 90,
#          'conmigo': 90,
#          'cabo': 89,
#          'entrar': 89,
#          'pensar': 89,
#          'sabía': 89,
#          'dando': 89,
#          'famoso': 88,
#          'pudiera': 88,
#          'fe': 88,
#          'cuento': 87,
#          'salió': 87,
#          'mira': 87,
#          'suele': 87,
#          'teresa': 87,
#          'mozo': 86,
#          'mañana': 86,
#          'puerta': 86,
#          'quisiera': 86,
#          'asno': 86,
#          'algunas': 85,
#          'pecho': 85,
#          'mesma': 85,
#          'habiendo': 85,
#          'dieron': 85,
#          'campo': 84,
#          'vuestras': 84,
#          'aún': 84,
#          'gana': 84,
#          'juicio': 83,
#          'pueden': 83,
#          'nuevas': 83,
#          'cuantos': 82,
#          'autor': 82,
#          'valor': 82,
#          'dejó': 82,
#          'trabajo': 82,
#          'sazón': 82,
#          'tras': 82,
#          'dé': 82,
#          'ti': 82,
#          'batalla': 81,
#          'natural': 80,
#          'llaman': 80,
#          'cuya': 80,
#          'libertad': 80,
#          'entendimiento': 79,
#          'quizá': 79,
#          'madre': 79,
#          'pensamiento': 78,
#          'peligro': 78,
#          'cerca': 78,
#          'locura': 78,
#          'marido': 78,
#          'sol': 78,
#          'pasó': 78,
#          'tenga': 78,
#          'allá': 78,
#          'misma': 77,
#          'desgracia': 77,
#          'pueda': 77,
#          'sean': 77,
#          'zoraida': 77,
#          'caballerías': 76,
#          'honra': 76,
#          'brazo': 76,
#          'falta': 76,
#          'mercedes': 76,
#          'agua': 76,
#          'rico': 76,
#          'seis': 76,
#          'criado': 75,
#          'presto': 75,
#          'hubiera': 75,
#          'haga': 75,
#          'doña': 75,
#          'sansón': 75,
#          'ama': 74,
#          'semejantes': 74,
#          'sucedió': 74,
#          'españa': 74,
#          'hoy': 74,
#          'eres': 74,
#          'podrá': 74,
#          'debajo': 74,
#          'dueña': 74,
#          'priesa': 73,
#          'valeroso': 73,
#          'remedio': 73,
#          'jumento': 73,
#          'fortuna': 73,
#          'nuestros': 73,
#          'silencio': 73,
#          'hacen': 72,
#          'reino': 72,
#          'cuán': 72,
#          'deseos': 72,
#          'venían': 72,
#          'condición': 71,
#          'e': 71,
#          'doncellas': 71,
#          'espacio': 71,
#          'labrador': 71,
#          'entró': 71,
#          'licencia': 71,
#          'halló': 70,
#          'llegar': 70,
#          'discreto': 70,
#          'cristiano': 70,
#          'padres': 70,
#          'cristianos': 70,
#          'leído': 69,
#          'hicieron': 69,
#          'fuere': 69,
#          'gracias': 69,
#          'haré': 69,
#          'llegaron': 69,
#          'quisiere': 69,
#          'vestido': 69,
#          'mandó': 68,
#          'pensaba': 68,
#          'suya': 67,
#          'tomó': 67,
#          'pasado': 67,
#          'suceso': 67,
#          'querría': 67,
#          'mayores': 66,
#          'tenían': 66,
#          'hazañas': 66,
#          'creer': 66,
#          'virtud': 66,
#          'bosque': 66,
#          'par': 66,
#          'espaldas': 66,
#          'leer': 65,
#          'luz': 65,
#          'muestras': 65,
#          'oír': 65,
#          'ánimo': 65,
#          'hago': 65,
#          'sangre': 65,
#          'antonio': 65,
#          'esperar': 65,
#          'barbas': 65,
#          'andar': 65,
#          'silla': 65,
#          'hemos': 65,
#          'hidalgo': 64,
#          'lanza': 64,
#          'llamaba': 64,
#          'querer': 64,
#          'señal': 64,
#          'pan': 64,
#          'tenido': 64,
#          'escuderos': 64,
#          'culpa': 64,
#          'criados': 64,
#          'amigos': 64,
#          'edad': 63,
#          '...': 63,
#          'grandeza': 63,
#          'maese': 63,
#          'ansí': 63,
#          'discurso': 63,
#          'noticia': 63,
#          'dije': 63,
#          'verde': 63,
#          'dormir': 62,
#          'hijos': 62,
#          'enemigo': 62,
#          'encantadores': 62,
#          'dónde': 62,
#          'altisidora': 62,
#          'queda': 61,
#          'consigo': 61,
#          'azotes': 61,
#          'daño': 61,
#          'sucesos': 61,
#          'obra': 61,
#          'sola': 61,
#          'compañía': 61,
#          'ahí': 60,
#          'ningún': 60,
#          'hallado': 60,
#          'tuviese': 60,
#          'haciendo': 60,
#          'temor': 60,
#          'oyendo': 60,
#          'diese': 60,
#          'dolor': 60,
#          'renegado': 60,
#          'carrasco': 60,
#          'cuyo': 59,
#          'resolución': 59,
#          'hambre': 59,
#          'hubiese': 59,
#          'dineros': 59,
#          'diez': 59,
#          'tienes': 59,
#          'quedaron': 59,
#          'paz': 59,
#          'provecho': 59,
#          'sobrina': 58,
#          'media': 58,
#          'diga': 58,
#          'vieron': 58,
#          'presente': 58,
#          'acabó': 58,
#          'mirar': 58,
#          'obras': 58,
#          'vea': 58,
#          'oídos': 58,
#          'principal': 58,
#          'mar': 58,
#          'pasaba': 57,
#          'nueva': 57,
#          'ante': 57,
#          'enamorado': 57,
#          '«': 57,
#          'estuvo': 57,
#          'venga': 57,
#          'libre': 57,
#          'valiente': 57,
#          'dijese': 57,
#          'vi': 57,
#          'pastor': 57,
#          'llama': 57,
#          'esposo': 57,
#          'encantado': 56,
#          'principio': 56,
#          'necesidad': 56,
#          'hallar': 56,
#          'quitar': 56,
#          'consejo': 56,
#          'lado': 56,
#          'oficio': 56,
#          'sois': 56,
#          'licenciado': 56,
#          'reina': 56,
#          'poeta': 56,
#          'caer': 56,
#          'veo': 56,
#          'princesa': 55,
#          'aldea': 55,
#          'reales': 55,
#          'alta': 55,
#          'encima': 55,
#          'responder': 55,
#          'destos': 55,
#          'suelen': 55,
#          'dueñas': 55,
#          'veinte': 54,
#          'lleno': 54,
#          'llamar': 54,
#          'darle': 54,
#          'mirando': 54,
#          'lejos': 54,
#          'acaso': 54,
#          'esperando': 54,
#          'aire': 54,
#          'discreción': 54,
#          'letras': 54,
#          'plática': 54,
#          'vencido': 54,
#          'ejercicio': 53,
#          'hacienda': 53,
#          'dentro': 53,
#          'prosiguió': 53,
#          'dejando': 53,
#          'destas': 53,
#          'miedo': 53,
#          'cuidado': 53,
#          'servir': 53,
#          'oyó': 53,
#          'blanca': 53,
#          'quieres': 53,
#          'doy': 53,
#          'fuego': 53,
#          'habrá': 53,
#          'carro': 53,
#          'acabar': 52,
#          'gigante': 52,
#          'verdadera': 52,
#          'contar': 52,
#          'mujeres': 52,
#          'iban': 52,
#          'risa': 52,
#          'diciéndole': 52,
#          'asimismo': 52,
#          'roque': 52,
#          'versos': 52,
#          'acuerdo': 52,
#          'moros': 52,
#          'daré': 52,
#          'escrito': 51,
#          'llegando': 51,
#          'servido': 51,
#          'presencia': 51,
#          'contó': 51,
#          'poca': 51,
#          'sucedido': 51,
#          'esposa': 51,
#          'sepa': 51,
#          'segunda': 51,
#          'voy': 51,
#          'negocio': 51,
#          'burla': 51,
#          'montesinos': 51,
#          'basilio': 51,
#          'claro': 50,
#          'supo': 50,
#          'señoras': 50,
#          'historias': 50,
#          'verdadero': 50,
#          'sacar': 50,
#          'presentes': 50,
#          'sacó': 49,
#          'puesta': 49,
#          'andaba': 49,
#          'huésped': 49,
#          'dejado': 49,
#          'ruido': 49,
#          'acá': 49,
#          'decís': 49,
#          'pesar': 49,
#          'trae': 49,
#          'bondad': 49,
#          'justicia': 49,
#          'deben': 49,
#          'enemigos': 49,
#          'fuerzas': 49,
#          'santa': 49,
#          'dan': 49,
#          'efecto': 49,
#          'disparates': 48,
#          'conocido': 48,
#          'verdaderamente': 48,
#          'paje': 48,
#          'salud': 48,
#          'hacia': 48,
#          'nuestras': 48,
#          'respuesta': 48,
#          'moro': 48,
#          'término': 48,
#          'blanco': 48,
#          'van': 48,
#          'dices': 48,
#          'pusieron': 48,
#          'vestidos': 48,
#          'especialmente': 48,
#          'diré': 48,
#          'personas': 48,
#          'perder': 47,
#          'género': 47,
#          'real': 47,
#          'propósito': 47,
#          'toca': 47,
#          'cinco': 47,
#          'pocos': 47,
#          'cólera': 47,
#          'sabes': 47,
#          'aquél': 47,
#          'vuelto': 47,
#          'pidió': 47,
#          'emperador': 47,
#          'esas': 47,
#          'quieren': 46,
#          'año': 46,
#          'imaginación': 46,
#          'efeto': 46,
#          'cabellos': 46,
#          'entiendo': 46,
#          'cortesía': 46,
#          'cargo': 46,
#          'venido': 46,
#          'mirad': 46,
#          'llegado': 46,
#          'todavía': 46,
#          'esté': 46,
#          'tarde': 46,
#          'fueran': 46,
#          'pesadumbre': 46,
#          'darme': 46,
#          'cabrero': 46,
#          'muestra': 46,
#          'primo': 46,
#          'cueva': 46,
#          'cuál': 45,
#          'sabio': 45,
#          'viento': 45,
#          'pudiese': 45,
#          'instante': 45,
#          'mesa': 45,
#          'peor': 45,
#          'conocer': 45,
#          'favor': 45,
#          'horas': 45,
#          'dueño': 45,
#          'árboles': 45,
#          'sueño': 45,
#          'esperanza': 45,
#          'estremo': 45,
#          'general': 45,
#          'escudos': 45,
#          'albarda': 45,
#          'basta': 44,
#          'amores': 44,
#          'vivo': 44,
#          'fuesen': 44,
#          'hechos': 44,
#          'tuvieron': 44,
#          'arriba': 44,
#          'anda': 44,
#          'capitán': 44,
#          'guerra': 44,
#          'gloria': 44,
#          'vamos': 44,
#          'desdichado': 44,
#          'honestidad': 44,
#          'belleza': 44,
#          'opinión': 44,
#          'ingenio': 44,
#          'llevaba': 44,
#          'corte': 44,
#          'leonela': 44,
#          'amadís': 43,
#          'tiempos': 43,
#          'cautivo': 43,
#          'buscando': 43,
#          'quedar': 43,
#          'subir': 43,
#          'diego': 43,
#          'contado': 43,
#          'adónde': 43,
#          'fuerte': 42,
#          'alto': 42,
#          'linaje': 42,
#          'éstos': 42,
#          'oyeron': 42,
#          'llamado': 42,
#          'clara': 42,
#          'doce': 42,
#          'jardín': 42,
#          'vaya': 42,
#          'largo': 42,
#          'mejores': 42,
#          'imposible': 42,
#          'venganza': 42,
#          'mono': 42,
#          'rodríguez': 42,
#          'llevó': 41,
#          'agravio': 41,
#          'siglos': 41,
#          'tornó': 41,
#          'armado': 41,
#          'mías': 41,
#          'pastores': 41,
#          'pedir': 41,
#          'primer': 41,
#          'abajo': 41,
#          'vuestros': 41,
#          'viaje': 41,
#          'alcanzar': 41,
#          'traje': 41,
#          'lleva': 41,
#          'verá': 41,
#          'escribir': 41,
#          'señas': 41,
#          'pasaron': 40,
#          'malos': 40,
#          'cama': 40,
#          'hallaron': 40,
#          'verse': 40,
#          'alzó': 40,
#          'hiciese': 40,
#          'veras': 40,
#          'costumbre': 40,
#          'esos': 40,
#          'vienen': 40,
#          'amistad': 40,
#          'seguro': 40,
#          'oidor': 40,
#          'duques': 40,
#          'quiteria': 40,
#          'señales': 39,
#          'dama': 39,
#          'rodillas': 39,
#          'podían': 39,
#          'dientes': 39,
#          'pide': 39,
#          'leguas': 39,
#          'contrario': 39,
#          'leyes': 39,
#          'di': 39,
#          'conciencia': 39,
#          'admiración': 39,
#          'míos': 39,
#          'trata': 38,
#          'deja': 38,
#          'perlas': 38,
#          'caminos': 38,
#          'donaire': 38,
#          'viejo': 38,
#          'paciencia': 38,
#          'díjole': 38,
#          'hará': 38,
#          'mire': 38,
#          'levantó': 38,
#          'parar': 38,
#          'salido': 38,
#          'luis': 38,
#          'volvieron': 38,
#          'diligencia': 38,
#          'cide': 38,
#          'dime': 38,
#          'yelmo': 38,
#          'discreta': 38,
#          'alegre': 38,
#          'papel': 38,
#          'barba': 38,
#          'dinero': 38,
#          'canónigo': 38,
#          'hacían': 37,
#          'viese': 37,
#          'mostraba': 37,
#          'gentil': 37,
#          'cualquiera': 37,
#          'luna': 37,
#          'juntos': 37,
#          'caído': 37,
#          'molido': 37,
#          'hecha': 37,
#          'conozco': 37,
#          'correr': 37,
#          'justo': 37,
#          'grado': 37,
#          'hamete': 37,
#          'uso': 37,
#          'mentira': 37,
#          'entrambos': 37,
#          'sala': 37,
#          'mayordomo': 37,
#          'experiencia': 36,
#          'labradora': 36,
#          'grandísimo': 36,
#          'tuviera': 36,
#          'haría': 36,
#          'baja': 36,
#          'desto': 36,
#          'obligado': 36,
#          'pasos': 36,
#          'morir': 36,
#          'palos': 36,
#          'echar': 36,
#          'galeras': 36,
#          'gentes': 36,
#          'sepultura': 36,
#          'iglesia': 36,
#          'tenemos': 36,
#          'vivir': 36,
#          'viniese': 36,
#          'reyes': 36,
#          'celada': 35,
#          'pedazos': 35,
#          'título': 35,
#          'creyendo': 35,
#          'encantador': 35,
#          'profesión': 35,
#          'pasados': 35,
#          'quedaba': 35,
#          'cumplir': 35,
#          'guardar': 35,
#          'estamos': 35,
#          'presteza': 35,
#          'asimesmo': 35,
#          'imagino': 35,
#          'dígame': 35,
#          'entrañas': 35,
#          'decían': 35,
#          'soldado': 35,
#          'ausencia': 35,
#          'locuras': 35,
#          'trabajos': 35,
#          'fui': 35,
#          'ricote': 35,
#          'industria': 34,
#          'llevado': 34,
#          'facilidad': 34,
#          'ocho': 34,
#          'moza': 34,
#          'lecho': 34,
#          'dellas': 34,
#          'acudió': 34,
#          'pagar': 34,
#          'parecen': 34,
#          'entraron': 34,
#          'cien': 34,
#          'punta': 34,
#          'vale': 34,
#          'coche': 34,
#          'éstas': 34,
#          'querido': 34,
#          'sale': 34,
#          'cristiana': 34,
#          'camacho': 34,
#          'hacerse': 33,
#          'deseaba': 33,
#          'dicha': 33,
#          'segundo': 33,
#          'cuello': 33,
#          'costa': 33,
#          'juro': 33,
#          'estás': 33,
#          'pláticas': 33,
#          'número': 33,
#          'calle': 33,
#          'dejaba': 33,
#          'engaño': 33,
#          'solos': 33,
#          'hice': 33,
#          'encantamento': 33,
#          'podré': 33,
#          'decirse': 33,
#          'barca': 33,
#          'serlo': 33,
#          'refranes': 33,
#          'leones': 33,
#          'jaula': 33,
#          'dolorida': 33,
#          'merece': 32,
#          'revés': 32,
#          'diera': 32,
#          'hablando': 32,
#          'riendas': 32,
#          'damas': 32,
#          'principales': 32,
#          'recebir': 32,
#          'esperaba': 32,
#          'llevaban': 32,
#          'alforjas': 32,
#          'ancas': 32,
#          'burlas': 32,
#          'andado': 32,
#          'ayuda': 32,
#          'viéndose': 32,
#          'juan': 32,
#          'queréis': 32,
#          'vive': 32,
#          'admirado': 32,
#          'ay': 32,
#          'ponerse': 32,
#          'daban': 32,
#          'somos': 32,
#          'temeroso': 32,
#          'seguir': 32,
#          'carne': 32,
#          'naturaleza': 32,
#          'cualquier': 32,
#          'recibió': 32,
#          'bacía': 32,
#          'mancebo': 32,
#          'llegaba': 31,
#          'valentía': 31,
#          'gigantes': 31,
#          'caminar': 31,
#          'verle': 31,
#          'golpe': 31,
#          'dejaron': 31,
#          'respeto': 31,
#          'rogó': 31,
#          'pone': 31,
#          'san': 31,
#          'puedes': 31,
#          'quedo': 31,
#          'dejase': 31,
#          'conoció': 31,
#          'suspiros': 31,
#          'francia': 31,
#          'salieron': 31,
#          'siquiera': 31,
#          'ventana': 31,
#          'volviéndose': 31,
#          'ganado': 31,
#          'condesa': 31,
#          'quisiese': 31,
#          'vuelta': 31,
#          'debió': 31,
#          'cruel': 31,
#          'sierra': 31,
#          'derecho': 31,
#          'echó': 31,
#          'maritornes': 31,
#          'doctor': 31,
#          'deje': 31,
#          'letra': 30,
#          'quitó': 30,
#          'lorenzo': 30,
#          'haberle': 30,
#          'vosotros': 30,
#          'sosiego': 30,
#          'solas': 30,
#          'viva': 30,
#          'momento': 30,
#          'gracia': 30,
#          'prometido': 30,
#          'mandado': 30,
#          'príncipes': 30,
#          'tomado': 30,
#          'hallo': 30,
#          'encantada': 30,
#          'acometer': 30,
#          'sobresalto': 30,
#          'volviese': 30,
#          'puestos': 30,
#          'descubierto': 30,
#          'forzoso': 30,
#          'verdaderas': 30,
#          'hábito': 30,
#          'crédito': 30,
#          'harto': 30,
#          'soldados': 30,
#          'sombra': 30,
#          'ventera': 30,
#          'tuve': 30,
#          'guarda': 30,
#          'diferentes': 30,
#          'llorar': 30,
#          'majestad': 30,
#          'estraño': 29,
#          'puertas': 29,
#          'enojo': 29,
#          'pensó': 29,
#          'parecido': 29,
#          'determinación': 29,
#          'decirle': 29,
#          'mesmos': 29,
#          'comenzaron': 29,
#          'muchacho': 29,
#          'volviendo': 29,
#          'villano': 29,
#          'acabado': 29,
#          'mulas': 29,
#          'levantar': 29,
#          'acudir': 29,
#          'determinado': 29,
#          'malas': 29,
#          'verás': 29,
#          'mula': 29,
#          'vizcaíno': 29,
#          'casas': 29,
#          'solamente': 29,
#          'suspenso': 29,
#          'términos': 29,
#          'particular': 29,
#          'mostró': 29,
#          'espejos': 29,
#          'hacerle': 29,
#          'vuelve': 29,
#          'hombros': 29,
#          'plaza': 28,
#          'salida': 28,
#          'famosos': 28,
#          'negro': 28,
#          'confuso': 28,
#          'calidad': 28,
#          'nacido': 28,
#          'tampoco': 28,
#          'nuevos': 28,
#          'debo': 28,
#          'ánima': 28,
#          'pareciéndole': 28,
#          'suplico': 28,
#          'derecha': 28,
#          'sano': 28,
#          'pensativo': 28,
#          'compadre': 28,
#          'artificio': 28,
#          'admirados': 28,
#          'promesas': 28,
#          'ínsulas': 28,
#          'treinta': 28,
#          'pequeño': 28,
#          'narices': 28,
#          'quiera': 28,
#          'hablado': 28,
#          'firme': 28,
#          'usar': 28,
#          'quisieres': 28,
#          'grisóstomo': 28,
#          'secreto': 28,
#          'infierno': 28,
#          'rostros': 28,
#          'cuyas': 28,
#          'malo': 28,
#          'partida': 28,
#          'señoría': 28,
#          'hallé': 28,
#          'retablo': 28,
#          'trifaldi': 28,
#          'carnes': 27,
#          'cartas': 27,
#          'hallaba': 27,
#          'hiciera': 27,
#          'servicio': 27,
#          'imaginar': 27,
#          'estuviese': 27,
#          'nombres': 27,
#          'empresa': 27,
#          'escudo': 27,
#          'ponga': 27,
#          'andaban': 27,
#          'determinó': 27,
#          'ladrón': 27,
#          'pedía': 27,
#          'último': 27,
#          'traído': 27,
#          'respondía': 27,
#          'siete': 27,
#          'despecho': 27,
#          'aliento': 27,
#          'tío': 27,
#          'pasada': 27,
#          'estómago': 27,
#          'color': 27,
#          'pendencia': 27,
#          'aguas': 27,
#          'marcela': 27,
#          'lugares': 27,
#          'cuentan': 27,
#          'ofreció': 27,
#          'acerca': 27,
#          'tratar': 27,
#          'conviene': 27,
#          'dirá': 27,
#          'barco': 27,
#          'excelencia': 27,
#          'infanta': 27,
#          'cuerdo': 27,
#          'tosilos': 27,
#          'altos': 26,
#          'gaula': 26,
#          'dulce': 26,
#          'subió': 26,
#          'ley': 26,
#          'yendo': 26,
#          'altas': 26,
#          'busca': 26,
#          'estraña': 26,
#          'pequeña': 26,
#          'semejante': 26,
#          'asió': 26,
#          'viéndole': 26,
#          'atrevido': 26,
#          'desnudo': 26,
#          'tercera': 26,
#          'poetas': 26,
#          'llevan': 26,
#          'hacerme': 26,
#          'gobernar': 26,
#          'traían': 26,
#          'piernas': 26,
#          'matar': 26,
#          'agradable': 26,
#          'voto': 26,
#          'duro': 26,
#          'valientes': 26,
#          'malicia': 26,
#          'esperanzas': 26,
#          'estudiante': 26,
#          'ricos': 26,
#          'ordenó': 26,
#          'desa': 26,
#          'diablos': 26,
#          'traza': 26,
#          'mover': 26,
#          'traer': 26,
#          'fácil': 26,
#          'médico': 26,
#          'tonto': 26,
#          'merlín': 26,
#          'sentido': 25,
#          'cierta': 25,
#          'necesario': 25,
#          'irse': 25,
#          'añadió': 25,
#          'árbol': 25,
#          'mes': 25,
#          'tendido': 25,
#          'castellano': 25,
#          'quitado': 25,
#          'den': 25,
#          'caña': 25,
#          'cuantas': 25,
#          'pocas': 25,
#          'abrió': 25,
#          'recebido': 25,
#          'vuelva': 25,
#          'jurar': 25,
#          'espero': 25,
#          'piedra': 25,
#          'furia': 25,
#          'aquélla': 25,
#          'puro': 25,
#          'pecador': 25,
#          'caída': 25,
#          'tomando': 25,
#          'quedan': 25,
#          'gracioso': 25,
#          'tendré': 25,
#          'reinos': 25,
#          'milagro': 25,
#          'tomé': 25,
#          'pasa': 25,
#          'piensa': 25,
#          'amiga': 25,
#          'pobres': 25,
#          'legua': 25,
#          'hermoso': 25,
#          'desventura': 25,
#          'honesta': 25,
#          'entrado': 25,
#          'limpio': 25,
#          'pecado': 25,
#          'miró': 25,
#          'toma': 25,
#          'comodidad': 25,
#          'verme': 25,
#          'bajel': 25,
#          'turcos': 25,
#          'lacayo': 25,
#          'maestresala': 25,
#          'caza': 24,
#          'veía': 24,
#          'satisfecho': 24,
#          'volvía': 24,
#          'apriesa': 24,
#          'trecho': 24,
#          'además': 24,
#          'ponía': 24,
#          'ligereza': 24,
#          'compañeros': 24,
#          'llegándose': 24,
#          'breves': 24,
#          'vecino': 24,
#          'quince': 24,
#          'juramento': 24,
#          'manda': 24,
#          'ayer': 24,
#          'preguntar': 24,
#          'larga': 24,
#          'echado': 24,
#          'aparte': 24,
#          'mostrar': 24,
#          'honrada': 24,
#          'gobernadores': 24,
#          'sintió': 24,
#          'alabanzas': 24,
#          'ejemplo': 24,
#          'aviso': 24,
#          'traigo': 24,
#          'sentado': 24,
#          'quise': 24,
#          'caballos': 24,
#          'rigor': 24,
#          'alcanza': 24,
#          'discretos': 24,
#          'infinitos': 24,
#          'desgracias': 24,
#          'estancia': 24,
#          'paño': 24,
#          'encantados': 24,
#          'pechos': 24,
#          'pude': 24,
#          'llega': 24,
#          'digna': 24,
#          'entrada': 24,
#          'dijeron': 24,
#          'mentecato': 24,
#          'gregorio': 24,
#          'importa': 23,
#          'parecían': 23,
#          'cielos': 23,
#          'simple': 23,
#          'golpes': 23,
#          'convenía': 23,
#          'patria': 23,
#          'talante': 23,
#          'corral': 23,
#          'conforme': 23,
#          'blancas': 23,
#          'teniendo': 23,
#          'venida': 23,
#          'fecho': 23,
#          'serán': 23,
#          'romance': 23,
#          'acertado': 23,
#          'propio': 23,
#          'importancia': 23,
#          'intento': 23,
#          'arremetió': 23,
#          'prosigue': 23,
#          'carga': 23,
#          'arte': 23,
#          'hízolo': 23,
#          'celos': 23,
#          'cantidad': 23,
#          'entendió': 23,
#          'atención': 23,
#          'vinieron': 23,
#          'juntamente': 23,
#          'usan': 23,
#          'sitio': 23,
#          'vee': 23,
#          'muerta': 23,
#          'perdido': 23,
#          'habido': 23,
#          'penitencia': 23,
#          'ponerme': 23,
#          'ido': 23,
#          'haz': 23,
#          'recio': 23,
#          'dejé': 23,
#          'vergüenza': 23,
#          'saliese': 23,
#          'liberal': 23,
#          'impertinente': 23,
#          'pobreza': 23,
#          'cuadrilleros': 23,
#          'visorrey': 23,
#          'desencanto': 23,
#          'roldán': 22,
#          'traidor': 22,
#          'puestas': 22,
#          'famosa': 22,
#          'llamó': 22,
#          'ordinario': 22,
#          'llegue': 22,
#          'lenguas': 22,
#          'tocar': 22,
#          'bastante': 22,
#          'pusiese': 22,
#          'talle': 22,
#          'diversas': 22,
#          'vela': 22,
#          'desenvoltura': 22,
#          'honrado': 22,
#          'consejos': 22,
#          'meses': 22,
#          'sacado': 22,
#          'cayó': 22,
#          'alegría': 22,
#          'invención': 22,
#          'salvo': 22,
#          'león': 22,
#          'refrán': 22,
#          'conde': 22,
#          'vencimiento': 22,
#          'roto': 22,
#          'detrás': 22,
#          'papeles': 22,
#          'paréceme': 22,
#          'yerbas': 22,
#          'conocimiento': 22,
#          'mostrado': 22,
#          'faltar': 22,
#          'cabras': 22,
#          'haberse': 22,
#          'riquezas': 22,
#          'miraba': 22,
#          'corona': 22,
#          'ejecución': 22,
#          'dura': 22,
#          'ponerle': 22,
#          'prado': 22,
#          'acaba': 22,
#          'desdichada': 22,
#          'tenéis': 22,
#          'llevo': 22,
#          'suyos': 22,
#          'vestida': 22,
#          'diferencia': 21,
#          'humilde': 21,
#          'hechas': 21,
#          'temiendo': 21,
#          'vendrá': 21,
#          'peso': 21,
#          'música': 21,
#          'liberalidad': 21,
#          'llena': 21,
#          'atrevimiento': 21,
#          'descuido': 21,
#          'miserable': 21,
#          'perjuicio': 21,
#          'trigo': 21,
#          'pagado': 21,
#          'sentimiento': 21,
#          'nací': 21,
#          'tome': 21,
#          'habla': 21,
#          'misericordia': 21,
#          'poesía': 21,
#          'escritos': 21,
#          'debían': 21,
#          'dará': 21,
#          'dándole': 21,
#          'sabían': 21,
#          'pelo': 21,
#          'temerosa': 21,
#          'halla': 21,
#          'ofrecimientos': 21,
#          'monte': 21,
#          'calles': 21,
#          'atento': 21,
#          'hermandad': 21,
#          'prueba': 21,
#          'soledad': 21,
#          'suspensos': 21,
#          'escuchando': 21,
#          'menor': 21,
#          'rica': 21,
#          'justas': 21,
#          'dijera': 21,
#          'ven': 21,
#          'labios': 21,
#          'grave': 21,
#          'lástima': 21,
#          'acabe': 21,
#          'jaez': 21,
#          'vas': 21,
#          'galeotes': 21,
#          'bellaco': 21,
#          'soneto': 21,
#          'pregunta': 21,
#          'cola': 21,
#          'daga': 21,
#          'demonio': 21,
#          'mora': 21,
#          'figuras': 21,
#          'zaragoza': 21,
#          'sanchica': 21,
#          'suyas': 20,
#          'estrellas': 20,
#          'batallas': 20,
#          'máquina': 20,
#          'hierro': 20,
#          'faltaba': 20,
#          'entiende': 20,
#          'sujeto': 20,
#          'puerto': 20,
#          'caballeriza': 20,
#          'patio': 20,
#          'campos': 20,
#          'mandar': 20,
#          'arriero': 20,
#          'arrojó': 20,
#          'brevedad': 20,
#          'estáis': 20,
#          'descubrió': 20,
#          'mozos': 20,
#          'verla': 20,
#          'quedará': 20,
#          'costillas': 20,
#          'cubierto': 20,
#          'diesen': 20,
#          'estilo': 20,
#          'válame': 20,
#          'vimos': 20,
#          'suceder': 20,
#          'felice': 20,
#          'viniere': 20,
#          'defensa': 20,
#          'flor': 20,
#          'quedado': 20,
#          'pintado': 20,
#          'montaña': 20,
#          'ruego': 20,
#          'andan': 20,
#          'dedo': 20,
#          'debes': 20,
#          'encierra': 20,
#          'persiguen': 20,
#          'segura': 20,
#          'bronce': 20,
#          'pastora': 20,
#          'ciencia': 20,
#          'cuándo': 20,
#          'movido': 20,
#          'enamorados': 20,
#          'recato': 20,
#          'vais': 20,
#          'miraban': 20,
#          'escribió': 20,
#          'confusión': 20,
#          'duerme': 20,
#          'acudieron': 20,
#          'mientras': 20,
#          'cuántas': 20,
#          'contigo': 20,
#          'guía': 20,
#          'poderoso': 20,
#          'comido': 20,
#          'ropa': 20,
#          'río': 20,
#          'hayan': 20,
#          'lienzo': 20,
#          'trecientos': 20,
#          'ignorante': 20,
#          'estuviera': 20,
#          'maravillas': 20,
#          'maravilla': 20,
#          'veis': 20,
#          'daría': 20,
#          'comedia': 20,
#          'argel': 20,
#          'adarga': 19,
#          'peligros': 19,
#          'llenas': 19,
#          'fortaleza': 19,
#          'compañero': 19,
#          'sevilla': 19,
#          'entendido': 19,
#          'humor': 19,
#          'ceremonias': 19,
#          'preguntóle': 19,
#          'trance': 19,
#          'tocaba': 19,
#          'defender': 19,
#          'andrés': 19,
#          'paga': 19,
#          'bella': 19,
#          'ojo': 19,
#          'sufrir': 19,
#          'desventuras': 19,
#          'fee': 19,
#          'vengo': 19,
#          'pudieran': 19,
#          'primeros': 19,
#          'sabré': 19,
#          'calla': 19,
#          'canto': 19,
#          'circunstantes': 19,
#          'espadas': 19,
#          'nación': 19,
#          'verdaderos': 19,
#          'acciones': 19,
#          'mirado': 19,
#          'cara': 19,
#          'menudo': 19,
#          'tuyo': 19,
#          'discretas': 19,
#          'entra': 19,
#          'hermanos': 19,
#          'durmiendo': 19,
#          'sabéis': 19,
#          'peña': 19,
#          'responde': 19,
#          'bendición': 19,
#          'cortés': 19,
#          'humana': 19,
#          'dedos': 19,
#          'carrera': 19,
#          'montañas': 19,
#          'llano': 19,
#          'do': 19,
#          'corta': 19,
#          'virtudes': 19,
#          'engañado': 19,
#          'yerba': 19,
#          'ah': 19,
#          'camisa': 19,
#          'despertó': 19,
#          'dejan': 19,
#          'llegóse': 19,
#          'bestias': 19,
#          'pudiere': 19,
#          'vencedor': 19,
#          'escondido': 19,
#          'muelas': 19,
#          'hubieran': 19,
#          'espanto': 19,
#          'digas': 19,
#          'quede': 19,
#          'prudente': 19,
#          'casado': 19,
#          'estrecheza': 19,
#          'desmayada': 19,
#          'secretario': 19,
#          'álvaro': 19,
#          'melisendra': 19,
#          'claudia': 19,
#          'imaginaba': 18,
#          'nicolás': 18,
#          'probar': 18,
#          'blanda': 18,
#          'plata': 18,
#          'humano': 18,
#          'piedras': 18,
#          'prometió': 18,
#          'servicios': 18,
#          'gallardo': 18,
#          'atado': 18,
#          'breve': 18,
#          'aquéllos': 18,
#          'pensado': 18,
#          'hilo': 18,
#          'proseguir': 18,
#          'canta': 18,
#          'herida': 18,
#          'necedades': 18,
#          'cuerpos': 18,
#          'despojos': 18,
#          'testamento': 18,
#          'desdichas': 18,
#          'rayos': 18,
#          'casos': 18,
#          'veas': 18,
#          'campaña': 18,
#          'improviso': 18,
#          'benengeli': 18,
#          'interés': 18,
#          'bálsamo': 18,
#          'prometida': 18,
#          'manteles': 18,
#          'queso': 18,
#          'comida': 18,
#          'redonda': 18,
#          'podéis': 18,
#          'gozar': 18,
#          'común': 18,
#          'sabido': 18,
#          'honesto': 18,
#          'premio': 18,
#          'sirva': 18,
#          'bienes': 18,
#          'roma': 18,
#          'persuadir': 18,
#          'corría': 18,
#          'huesos': 18,
#          'tengan': 18,
#          'docientos': 18,
#          'lanzón': 18,
#          'profundo': 18,
#          'frío': 18,
#          'espíritu': 18,
#          'bajo': 18,
#          'perro': 18,
#          'ruegos': 18,
#          'corre': 18,
#          'escuadrón': 18,
#          'salario': 18,
#          'freno': 18,
#          'saque': 18,
#          'usa': 18,
#          'contenta': 18,
#          'posesión': 18,
#          'ducados': 18,
#          'huir': 18,
#          'prudencia': 18,
#          'cueros': 18,
#          'querían': 18,
#          'morena': 18,
#          'turco': 18,
#          'parientes': 18,
#          'aires': 18,
#          'alegres': 18,
#          'levantándose': 18,
#          'cautivos': 18,
#          'carreta': 18,
#          'leandra': 18,
#          'malambruno': 18,
#          'clavileño': 18,
#          'antigua': 17,
#          'heridas': 17,
#          'promesa': 17,
#          'encantamentos': 17,
#          'entera': 17,
#          'parecerle': 17,
#          'estruendo': 17,
#          'pecados': 17,
#          'agravios': 17,
#          'terrible': 17,
#          'seas': 17,
#          'detuvo': 17,
#          'perdón': 17,
#          'abundancia': 17,
#          'seguridad': 17,
#          'acabada': 17,
#          'menesterosos': 17,
#          'quedase': 17,
#          'llenos': 17,
#          'puntualidad': 17,
#          'continente': 17,
#          'reposo': 17,
#          'veréis': 17,
#          'supiese': 17,
#          'tendría': 17,
#          'encina': 17,
#          'prometo': 17,
#          'castigo': 17,
#          'mandamiento': 17,
#          'seda': 17,
#          'ora': 17,
#          'usanza': 17,
#          'vía': 17,
#          'malandrines': 17,
#          'flores': 17,
#          'espejo': 17,
#          'ése': 17,
#          'tesoro': 17,
#          'llamada': 17,
#          'precio': 17,
#          'arzobispo': 17,
#          'solía': 17,
#          'procura': 17,
#          'descubrieron': 17,
#          'desear': 17,
#          'hallarse': 17,
#          'comenzado': 17,
#          'olvido': 17,
#          'ofrecía': 17,
#          'oí': 17,
#          'desmayo': 17,
#          'llegase': 17,
#          'cabreros': 17,
#          'estuvieron': 17,
#          'fuente': 17,
#          'justa': 17,
#          'saben': 17,
#          'amantes': 17,
#          'levantaron': 17,
#          'pasase': 17,
#          'mármol': 17,
#          'consideración': 17,
#          'mortal': 17,
#          'sentidos': 17,
#          'sospecha': 17,
#          'sed': 17,
#          'discursos': 17,
#          'recado': 17,
#          'palo': 17,
#          'compasión': 17,
#          'poniendo': 17,
#          'huyendo': 17,
#          'infinitas': 17,
#          'diere': 17,
#          'siguiente': 17,
#          'sentencias': 17,
#          'cadena': 17,
#          'garganta': 17,
#          'ginés': 17,
#          'llevaron': 17,
#          'vulgo': 17,
#          'vuelvo': 17,
#          'casar': 17,
#          'bueyes': 17,
#          'remo': 17,
#          'berbería': 17,
#          'come': 17,
#          'vicente': 17,
#          'ingenioso': 16,
#          'vivía': 16,
#          'rocín': 16,
#          'salga': 16,
#          'pasaban': 16,
#          'quienquiera': 16,
#          'podido': 16,
#          'pudieron': 16,
#          'mandaba': 16,
#          'beber': 16,
#          'cena': 16,
#          'ansimesmo': 16,
#          'dondequiera': 16,
#          'sosegado': 16,
#          'atrás': 16,
#          'creyó': 16,
#          'cuánto': 16,
#          'dejaré': 16,
#          'placer': 16,
#          'viven': 16,
#          'rato': 16,
#          'siguió': 16,
#          'molde': 16,
#          'espuelas': 16,
#          'llevando': 16,
#          'acordó': 16,
#          'paredes': 16,
#          'pase': 16,
#          'enfermedad': 16,
#          'ciento': 16,
#          'pondré': 16,
#          'quisieren': 16,
#          'enamorada': 16,
#          'vitoria': 16,
#          'demasiadamente': 16,
#          'envidia': 16,
#          'antiguos': 16,
#          'sabrá': 16,
#          'tiento': 16,
#          'naturales': 16,
#          'falto': 16,
#          'conocía': 16,
#          'concierto': 16,
#          'hubiere': 16,
#          'ganar': 16,
#          'cuesta': 16,
#          'subieron': 16,
#          'atentamente': 16,
#          'estacas': 16,
#          'ajena': 16,
#          'favorecer': 16,
#          'cantar': 16,
#          'rogar': 16,
#          'bendito': 16,
#          'consintió': 16,
#          'ambrosio': 16,
#          'principalmente': 16,
#          'labradores': 16,
#          'verano': 16,
#          'envía': 16,
#          'quejas': 16,
#          'temer': 16,
#          'contando': 16,
#          'regalo': 16,
#          'respondiese': 16,
#          'verdades': 16,
#          'soga': 16,
#          'darte': 16,
#          'iguales': 16,
#          'dígolo': 16,
#          'deso': 16,
#          'ventaja': 16,
#          'fermosa': 16,
#          'adorno': 16,
#          'curioso': 16,
#          'abrazó': 16,
#          'entrambas': 16,
#          'hablaba': 16,
#          'colores': 16,
#          'ea': 16,
#          'volverse': 16,
#          'tristeza': 16,
#          'alas': 16,
#          'deshora': 16,
#          'salí': 16,
#          'habló': 16,
#          'apostaré': 16,
#          'confieso': 16,
#          'muchachos': 16,
#          'parezca': 16,
#          'escribano': 16,
#          'disparate': 16,
#          'maleta': 16,
#          'contentos': 16,
#          'habrán': 16,
#          'ejercicios': 16,
#          'comedias': 16,
#          'respondido': 16,
#          'entero': 16,
#          'joyas': 16,
#          'dijere': 16,
#          'costumbres': 16,
#          'micomicona': 16,
#          'novela': 16,
#          'bodas': 16,
#          'marién': 16,
#          'gaiferos': 16,
#          'ana': 16,
#          'noches': 15,
#          'cincuenta': 15,
#          'seco': 15,
#          'curiosidad': 15,
#          'fermosura': 15,
#          'pluma': 15,
#          'dello': 15,
#          'propuso': 15,
#          'jornada': 15,
#          'hermosas': 15,
#          'humildad': 15,
#          'alabanza': 15,
#          'pedido': 15,
#          'reír': 15,
#          'ajenas': 15,
#          'pago': 15,
#          'amparo': 15,
#          'dejasen': 15,
#          'brío': 15,
#          'negra': 15,
#          'toque': 15,
#          'diole': 15,
#          'azote': 15,
#          'sirve': 15,
#          'asiéndole': 15,
#          'satisfación': 15,
#          'confesar': 15,
#          'marqués': 15,
#          'cabestro': 15,
#          'escribe': 15,
#          'viesen': 15,
#          'cuchilladas': 15,
#          'simplicidad': 15,
#          'compuesto': 15,
#          'sigue': 15,
#          'santo': 15,
#          'habilidad': 15,
#          'libres': 15,
#          'grandezas': 15,
#          'miguel': 15,
#          'prendas': 15,
#          'cerrada': 15,
#          'levantado': 15,
#          'quédese': 15,
# ...
#          'ligaba': 1,
#          'interrumpidas': 1,
#          'confirmóse': 1,
#          'albergase': 1,
#          'alemanes': 1,
#          'desenterrar': 1,
#          'enriquece': 1,
#          'integridad': 1,
#          'usadla': 1,
#          'ofenderos': 1,
#          'convenimos': 1,
#          'esotras': 1,
#          'determinados': 1,
#          'cometieron': 1,
#          'ahorcase': 1,
#          'helada': 1,
#          'procuraron': 1,
#          'dudaron': 1,
#          'confiar': 1,
#          'fióle': 1,
#          'firmados': 1,
#          'acariciase': 1,
#          'lxiv': 1,
#          'recibióla': 1,
#          'tañida': 1,
#          'espediente': 1,
#          'peleares': 1,
#          'venciere': 1,
#          'absteniéndote': 1,
#          'recojas': 1,
#          'retires': 1,
#          'vencieres': 1,
#          'desafiaba': 1,
#          'severo': 1,
#          'procurárades': 1,
#          'desengañara': 1,
#          'diciéndoos': 1,
#          'acertáis': 1,
#          'aceto': 1,
#          'exceto': 1,
#          'díchoselo': 1,
#          'precedencia': 1,
#          'acetación': 1,
#          'perplejo': 1,
#          'pudiéndose': 1,
#          'dense': 1,
#          'tercios': 1,
#          'andados': 1,
#          'defraude': 1,
#          'retire': 1,
#          'descubriéronle': 1,
#          'apesarado': 1,
#          'escurecida': 1,
#          'lxv': 1,
#          'siguiéronle': 1,
#          'persiguiéronle': 1,
#          'encerróse': 1,
#          'negároslo': 1,
#          'desarma': 1,
#          'descubráis': 1,
#          'desvaríos': 1,
#          'perdemos': 1,
#          'feliz': 1,
#          'liar': 1,
#          'marrido': 1,
#          'consolábale': 1,
#          'alégrese': 1,
#          'alegróse': 1,
#          'obligara': 1,
#          'tomarles': 1,
#          'desmayar': 1,
#          'codiciada': 1,
#          'aprietos': 1,
#          'adelantaba': 1,
#          'bogado': 1,
#          'reincorporóse': 1,
#          'redújose': 1,
#          'trató': 1,
#          'negociarlo': 1,
#          'salazar': 1,
#          'contaminado': 1,
#          'cauterio': 1,
#          'molifica': 1,
#          'fraudes': 1,
#          'deslumbrar': 1,
#          'argos': 1,
#          'brotar': 1,
#          'venenosos': 1,
#          'desembarazada': 1,
#          'filipo': 1,
#          'encargado': 1,
#          'gustará': 1,
#          'decretado': 1,
#          'ofrecióle': 1,
#          'lxvi': 1,
#          'alcanzadas': 1,
#          'escurecieron': 1,
#          'enseña': 1,
#          'gallarín': 1,
#          'presunciones': 1,
#          'atrevíme': 1,
#          'derribáronme': 1,
#          'pedestre': 1,
#          'acreditaré': 1,
#          'noviciado': 1,
#          'cobraremos': 1,
#          'incite': 1,
#          'ocupando': 1,
#          'pidiere': 1,
#          'midiere': 1,
#          'cuélguense': 1,
#          'grabaremos': 1,
#          'galardón': 1,
#          'castíguese': 1,
#          'revienten': 1,
#          'rotas': 1,
#          'mansedumbres': 1,
#          'caminen': 1,
#          'rectitud': 1,
#          'desafió': 1,
#          'igualarían': 1,
#          'gordo.': 1,
#          'impidan': 1,
#          'estorben': 1,
#          'escamonde': 1,
#          'monde': 1,
#          'entresaque': 1,
#          'pula': 1,
#          'atilde': 1,
#          'ajustará': 1,
#          'descarne': 1,
#          'llevemos': 1,
#          'llueva': 1,
#          'tris': 1,
#          'azcona': 1,
#          'chuzo': 1,
#          'defraudarme': 1,
#          'cartero': 1,
#          'sucedióme': 1,
#          'traguito': 1,
#          'rajitas': 1,
#          'llamativo': 1,
#          'escancie': 1,
#          'persuades': 1,
#          'contrahecho': 1,
#          'hártate': 1,
#          'esperándote': 1,
#          'desalforjó': 1,
#          'panecillo': 1,
#          'despabilaron': 1,
#          'lamieron': 1,
#          'encontrasen': 1,
#          'sacudido': 1,
#          'migajas': 1,
#          'antecogió': 1,
#          'lxvii': 1,
#          'fatigaron': 1,
#          'picaban': 1,
#          'forzosa': 1,
#          'preguntaste': 1,
#          'boberías': 1,
#          'inquirir': 1,
#          'quísome': 1,
#          'maldíjome': 1,
#          'vituperóme': 1,
#          'quejóse': 1,
#          'entregadas': 1,
#          'acuerdos': 1,
#          'azotarte': 1,
#          'gusanos': 1,
#          'desencantos': 1,
#          'untaos': 1,
#          'desencantado': 1,
#          'bizarras': 1,
#          'convirtiésemos': 1,
#          'compraré': 1,
#          'andaremos': 1,
#          'endechando': 1,
#          'caudalosos': 1,
#          'daránnos': 1,
#          'abundantísima': 1,
#          'matizadas': 1,
#          'estendidos': 1,
#          'cuadrado': 1,
#          'esquinado': 1,
#          'sansonino': 1,
#          'miculoso': 1,
#          'boscán': 1,
#          'nemoroso': 1,
#          'derivativo': 1,
#          'cansarme': 1,
#          'teresona': 1,
#          'celebrándola': 1,
#          'churumbelas': 1,
#          'gaitas': 1,
#          'zamoranas': 1,
#          'tamborines': 1,
#          'rabeles': 1,
#          'diferencias': 1,
#          'resuena': 1,
#          'chapas': 1,
#          'armónico': 1,
#          'tamborín': 1,
#          'almohaza': 1,
#          'alhucema': 1,
#          'borceguí': 1,
#          'zaquizamí': 1,
#          'alhelí': 1,
#          'alfaquí': 1,
#          'hanos': 1,
#          'collares': 1,
#          'guitarristas': 1,
#          'copleros': 1,
#          'quejaré': 1,
#          'alabarás': 1,
#          'polidas': 1,
#          'cuchares': 1,
#          'natas': 1,
#          'granjeen': 1,
#          'trasquilada': 1,
#          'quitada': 1,
#          'ojinegra': 1,
#          'reprehendiendo': 1,
#          'ensártalos': 1,
#          'tráeslos': 1,
#          'arrastras': 1,
#          'guías': 1,
#          'retiráronse': 1,
#          'lxviii': 1,
#          'cerdosa': 1,
#          'desvelaron': 1,
#          'cantas': 1,
#          'ayuno': 1,
#          'desalentado': 1,
#          'serenidad': 1,
#          'desvíate': 1,
#          'pesados': 1,
#          'dicipline': 1,
#          'endurecida': 1,
#          'propincuas': 1,
#          'post': 1,
#          'tenebras': 1,
#          'spero': 1,
#          'lucem': 1,
#          'ahuyenta': 1,
#          'calienta': 1,
#          'compran': 1,
#          'agazapó': 1,
#          'feria': 1,
#          'bufar': 1,
#          'ensordecieron': 1,
#          'estendida': 1,
#          'gruñidora': 1,
#          'déjalos': 1,
#          'adivas': 1,
#          'piquen': 1,
#          'avispas': 1,
#          'hollen': 1,
#          'tornémonos': 1,
#          'desfogaré': 1,
#          'madrigalete': 1,
#          'coplee': 1,
#          'acurrucó': 1,
#          'fianzas': 1,
#          'distingue': 1,
#          'esperezóse': 1,
#          'estirándose': 1,
#          'declinar': 1,
#          'arbolando': 1,
#          'punzaba': 1,
#          'apresuraron': 1,
#          'caminad': 1,
#          'trogloditas': 1,
#          'pagad': 1,
#          'antropófagos': 1,
#          'quejéis': 1,
#          'scitas': 1,
#          'abráis': 1,
#          'polifemos': 1,
#          'tortolitas': 1,
#          'estropajos': 1,
#          'perritas': 1,
#          'contentan': 1,
#          'parva': 1,
#          'ojalá': 1,
#          'váleme': 1,
#          'viéronle': 1,
#          'lxix': 1,
#          'arrebatadamente': 1,
#          'blandones': 1,
#          'quinientas': 1,
#          'levantaba': 1,
#          'dosel': 1,
#          'odoríferas': 1,
#          'amarilla': 1,
#          'señalaran': 1,
#          'humillación': 1,
#          'penitenciados': 1,
#          'echarían': 1,
#          'veíase': 1,
#          'quemaban': 1,
#          'volviósela': 1,
#          'abrasan': 1,
#          'sumiso': 1,
#          'improvisa': 1,
#          'suavísima': 1,
#          'vistieren': 1,
#          'picote': 1,
#          'vistiere': 1,
#          'cantaré': 1,
#          'estigio': 1,
#          'conducida': 1,
#          'celebrándote': 1,
#          'representarnos': 1,
#          'lite': 1,
#          'inescrutables': 1,
#          'decláralo': 1,
#          'sellad': 1,
#          'sellar': 1,
#          'regostóse': 1,
#          'bledos': 1,
#          'azótanme': 1,
#          'hanla': 1,
#          'acribarme': 1,
#          'acardenalarme': 1,
#          'ablándate': 1,
#          'humíllate': 1,
#          'nembrot': 1,
#          'mamonado': 1,
#          'acrebillado': 1,
#          'gemir': 1,
#          'cumplid': 1,
#          'nacistes': 1,
#          'bramando': 1,
#          'gatéenme': 1,
#          'traspásenme': 1,
#          'dagas': 1,
#          'buidas': 1,
#          'atenácenme': 1,
#          'martirio': 1,
#          'desencantes': 1,
#          'resucites': 1,
#          'mamona': 1,
#          'sellada': 1,
#          'oliendo': 1,
#          'vinagrillo': 1,
#          'sellaron': 1,
#          'punzamiento': 1,
#          'alfileres': 1,
#          'infernales': 1,
#          'supina': 1,
#          'depusiese': 1,
#          'rebullir': 1,
#          'sazonada': 1,
#          'eficacia': 1,
#          'hojuelas': 1,
#          'atármela': 1,
#          'pesaría': 1,
#          'aclamaban': 1,
#          'levantáronse': 1,
#          'bajarla': 1,
#          'poseo': 1,
#          'dispón': 1,
#          'dejarían': 1,
#          'lxx': 1,
#          'escusadas': 1,
#          'carriola': 1,
#          'escusarla': 1,
#          'dolores': 1,
#          'viniérale': 1,
#          'salióle': 1,
#          'mortíferos': 1,
#          'muriérase': 1,
#          'enamoré': 1,
#          'desdeñé': 1,
#          'habérmelas': 1,
#          'confundidas': 1,
#          'durmiéronse': 1,
#          'buscó': 1,
#          'llevándolo': 1,
#          'contóselo': 1,
#          'retirarse': 1,
#          'aparatos': 1,
#          'desatados': 1,
#          'tunicela': 1,
#          'sembrada': 1,
#          'ébano': 1,
#          'colchas': 1,
#          'acertase': 1,
#          'recatadas': 1,
#          'atropellan': 1,
#          'reventó': 1,
#          'condoliéndose': 1,
#          'depositó': 1,
#          'depositarlos': 1,
#          'agradeciera': 1,
#          'valonas': 1,
#          'guarnecidas': 1,
#          'flamencas': 1,
#          'pelotas': 1,
#          'jugadores': 1,
#          'regañaban': 1,
#          'maldecían': 1,
#          'voleo': 1,
#          'encuadernado': 1,
#          'papirotazo': 1,
#          'quitádmele': 1,
#          'metedle': 1,
#          'peloteando': 1,
#          'adamo': 1,
#          'remediados': 1,
#          'retiréis': 1,
#          'enojarse': 1,
#          'alterarse': 1,
#          'almirez': 1,
#          'cuesco': 1,
#          'dátil': 1,
#          'terco': 1,
#          'arremeto': 1,
#          'camellos': 1,
#          'doliese': 1,
#          'morirme': 1,
#          'créalo': 1,
#          'cantado': 1,
#          'panegírico': 1,
#          'maraville': 1,
#          'intonsos': 1,
#          'hurte': 1,
#          'atribuya': 1,
#          'estorbáronlo': 1,
#          'zahúrda': 1,
#          'menearán': 1,
#          'randera': 1,
#          'ocupadas': 1,
#          'tareas': 1,
#          'pestañas': 1,
#          'borrarán': 1,
#          'abominable': 1,
#          'cantara': 1,
#          'lxxi': 1,
#          'físicos': 1,
#          'cedulilla': 1,
#          'cátalo': 1,
#          'cantusado': 1,
#          'untar': 1,
#          'gratis': 1,
#          'impidiese': 1,
#          'probarlo': 1,
#          'azótate': 1,
#          'págate': 1,
#          'disponerme': 1,
#          'interesado': 1,
#          'minas': 1,
#          'pagarte': 1,
#          'montan': 1,
#          'desfalcaré': 1,
#          'abrevies': 1,
#          'abriré': 1,
#          'esperada': 1,
#          'ajustan': 1,
#          'amenos': 1,
#          'vacías': 1,
#          'flexible': 1,
#          'aguarden': 1,
#          'apresurarte': 1,
#          'dieres': 1,
#          'favorézcate': 1,
#          'consistir': 1,
#          'desnudóse': 1,
#          'arrebatando': 1,
#          'desmayes': 1,
#          'imprudencia': 1,
#          'zamora': 1,
#          'sobrecarga': 1,
#          'quebrados': 1,
#          'apártese': 1,
#          'levadas': 1,
#          'sobrará': 1,
#          'pégate': 1,
#          'contendré': 1,
#          'cobres': 1,
#          'ferreruelo': 1,
#          'resfriarme': 1,
#          'abrigó': 1,
#          'reconoció': 1,
#          'rastrillos': 1,
#          'vencieron': 1,
#          'alojáronle': 1,
#          'guadameciles': 1,
#          'menalao': 1,
#          'fragata': 1,
#          'verter': 1,
#          'desdichadísimas': 1,
#          'encontrara': 1,
#          'destruida': 1,
#          'paris': 1,
#          'escusaran': 1,
#          'bodegón': 1,
#          'pintasen': 1,
#          'zorra': 1,
#          'mauleón': 1,
#          'deum': 1,
#          'llegaremos': 1,
#          'enmendaré': 1,
#          'lxxii': 1,
#          'hojeé': 1,
#          'preguntaremos': 1,
#          'enjaezada': 1,
#          'importar': 1,
#          'palmease': 1,
#          'frión': 1,
#          'llovidas': 1,
#          'tutor': 1,
#          'burlería': 1,
#          'perseguirme': 1,
#          'nuncio': 1,
#          'curen': 1,
#          'albergue': 1,
#          'honrarse': 1,
#          'avellaneda': 1,
#          'jurídicamente': 1,
#          'partiéronse': 1,
#          'apartaban': 1,
#          'auténticamente': 1,
#          'reconocer': 1,
#          'lxxiii': 1,
#          'acreditan': 1,
#          'riñendo': 1,
#          'periquillo': 1,
#          'aplicando': 1,
#          'significar': 1,
#          'queríale': 1,
#          'agazapar': 1,
#          'cogióla': 1,
#          'presentósela': 1,
#          'presupongamos': 1,
#          'faltriquera': 1,
#          'dióselos': 1,
#          'rompidos': 1,
#          'desbaratados': 1,
#          'hincapié': 1,
#          'pasemos': 1,
#          'diósela': 1,
#          'repostero': 1,
#          'vistieron': 1,
#          'acomodóle': 1,
#          'abrazólos': 1,
#          'linces': 1,
#          'escusados': 1,
#          'divisaron': 1,
#          'despeado': 1,
#          'cinto': 1,
#          'traspasarla': 1,
#          'ejercitándose': 1,
#          'impedidos': 1,
#          'compraría': 1,
#          'vendrían': 1,
#          'curambro': 1,
#          'concedieron': 1,
#          'aprobaron': 1,
#          'ofreciéndosele': 1,
#          'compondré': 1,
#          'entretengamos': 1,
#          'retule': 1,
#          'grabe': 1,
#          'hipérbole': 1,
#          'buscaremos': 1,
#          'mañeruelas': 1,
#          'cuadraren': 1,
#          'esquinen': 1,
#          'faltaren': 1,
#          'darémosles': 1,
#          'estampadas': 1,
#          'fílidas': 1,
#          'amarilis': 1,
#          'fléridas': 1,
#          'belisardas': 1,
#          'venden': 1,
#          'celebraré': 1,
#          'anarda': 1,
#          'llamaré': 1,
#          'francenia': 1,
#          'lucinda': 1,
#          'cofadría': 1,
#          'teresaina': 1,
#          'vacase': 1,
#          'forzosas': 1,
#          'aconsejaron': 1,
#          'pastorcillo': 1,
#          'pastorcico': 1,
#          'alcacel': 1,
#          'zampoñas': 1,
#          'serenos': 1,
#          'robustos': 1,
#          'curtidos': 1,
#          'lxxiv': 1,
#          'eternas': 1,
#          'declinación': 1,
#          'arraigó': 1,
#          'alegrarle': 1,
#          'écloga': 1,
#          'sanazaro': 1,
#          'comprados': 1,
#          'barcino': 1,
#          'butrón': 1,
#          'desabrimientos': 1,
#          'tirón': 1,
#          'abrevian': 1,
#          'pareciéronle': 1,
#          'caliginosas': 1,
#          'confesarme': 1,
#          'profanas': 1,
#          'escarmentando': 1,
#          'abomino': 1,
#          'déjense': 1,
#          'traíganme': 1,
#          'miráronse': 1,
#          'conjeturaron': 1,
#          'confesóle': 1,
#          'llorosas': 1,
#          'pucheros': 1,
#          'empujón': 1,
#          'sobrare': 1,
#          'restante': 1,
#          'derribarse': 1,
#          'averiguare': 1,
#          'distribuir': 1,
#          'pías': 1,
#          'pidan': 1,
#          'escribirlos': 1,
#          'brindaba': 1,
#          'regocijaba': 1,
#          'heredar': 1,
#          'sacramentos': 1,
#          'compasiones': 1,
#          'inacabables': 1,
#          'contendiesen': 1,
#          'ahijársele': 1,
#          'contendieron': 1,
#          'quedarás': 1,
#          'espetera': 1,
#          'alambre': 1,
#          'péñola': 1,
#          'presuntuosos': 1,
#          'descuelgan': 1,
#          'profanarte': 1,
#          'folloncicos': 1,
#          'tocada': 1,
#          'tordesillesco': 1,
#          'atrever': 1,
#          'deliñada': 1,
#          'resfriado': 1,
#          'advertirás': 1,
#          'fuesa': 1,
#          'aconsejando': 1,
#          'enteramente': 1})
# 22639

# %% [markdown]
# __Exercise 2.__ Now, plot the same but use _logarithmic_ $x$ and $y$ axes.
#
# ---
#
# If our distribution is a powerlaw, this plot should be a straight line, whose slope is $a$
# and intercept is $\log c$. If we put back the $b$ parameter, it distorts a bit the
# low values, so in order to estimate $a$ and $c$ we have to pay attention to the large values.
#
# __You can try different preprocessing steps to see whether the distribution is closer to a powerlaw or not. For example, if you do not stem you may obtain a distribution that resembles more a powerlaw.__
#
# ---

# %%
# Contar las palabras y ordenarlas en orden decreciente (hacer un grafico para poder ver los resultados) hacer una regresion lineal
# para encontrar el exponente de la pendiente
from nltk.tokenize import word_tokenize
import matplotlib as mpl
import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from collections import Counter
import string
import urllib.request
import math

target_url = "https://fegalaz.usc.es/~gamallo/aulas/lingcomputacional/corpus/quijote-es.txt"

data = urllib.request.urlopen(target_url)

# Primero tokenizamos el texto
text = data.read().decode('latin-1')
text = text.replace("-"," ").replace("¿"," ").replace("¡"," ")

tokenized_text = word_tokenize(text)

# Luego filtramos el texto para poner todas las palabras en minuscula
spanish_sw = set(list(string.punctuation))
filtered_tokenized_text = [w.lower() for w in tokenized_text if w not in spanish_sw]

word_counts = Counter(filtered_tokenized_text)

# Obtener las palabras y sus frecuencias ordenadas de mayor a menor
most_common = word_counts.most_common(500) 

position = list(range(len(most_common)))
counts = [count for word, count in most_common]
counts = list(map(lambda x: math.log(x), counts))
position = list(map(lambda y: math.log(y), position))

# Graficar en escala log-log
plt.figure(figsize=(24, 12))
plt.plot(position, counts)
plt.xticks(rotation=45, ha="right")
plt.xlabel('Rango de palabra')
plt.ylabel('Frecuencia')
plt.title('Frecuencia de las 500 palabras más comunes en Don Quijote (escala log-log)')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 35
#      33 counts = [count for word, count in most_common]
#      34 counts = list(map(lambda x: math.log(x), counts))
# ---> 35 position = list(map(lambda y: math.log(y), position))
#      37 # Graficar en escala log-log
#      38 plt.figure(figsize=(24, 12))
#
# Cell In[72], line 35, in <lambda>(y)
#      33 counts = [count for word, count in most_common]
#      34 counts = list(map(lambda x: math.log(x), counts))
# ---> 35 position = list(map(lambda y: math.log(y), position))
#      37 # Graficar en escala log-log
#      38 plt.figure(figsize=(24, 12))
#
# ValueError: math domain error

# %% [markdown]
# __Exercise 3.__ Let's find $a$ and $c$ analytically.
# Assume we have $\log y = a \cdot \log x + \log c$.
#
# Take two distinct _large_ values of $x$, find their corresponding values of $y$,
# set up a system of two linear equations, and solve for $a$ and $c$.
# The solution will probably not fit very well the low values of $x$. You can try to
# make it better by adding the $b$ parameter, but don't agonize over it.
#
# Alternatively, use linear regression to estimate the _slope_  ($a$ parameter) and the intercept ($\log c$ parameter).

# %% [markdown]
# ---
#
# __Exercise 4.__  Now, it is time to check whether Heap's law applies in the _Don Quijote_. First, plot number of different words (word _types_) as a function of text length. Next, plot it on a log-log scale. You should see a straight line. Finally, give an estimate of $\beta$ parameter of Heap's law:
#
# $$  d = k \cdot N^{\beta} $$
#
# ---

# %% [markdown]
# ## 4. Rules of delivery
#
# - To be solved in _pairs_.
#
# - No plagiarism; don't discuss your work with other teams. You can ask for help to others for simple things, such as recalling a python instruction or module, but nothing too specific to the session.
#
# - If you feel you are spending much more time than the rest of the classmates, ask us for help. Questions can be asked either in person or by email, and you'll never be penalized by asking questions, no matter how stupid they look in retrospect.
#
# - Write a short report listing the solutions to the exercises proposed. Include things like: how did you find the best $a$, $b$, $c$ parameter values for the text laws? Please include plots that compare the fitted powerlaws with the real data (preferably in log-log scale). You are welcome to add conclusions and findings that depart from what we asked you to do. We encourage you to discuss the difficulties you find; this lets us give you help and also improve the lab session for future editions.
#
# - Turn the report to PDF. Make sure it has your names, date, and title.
#
# - Submit your work through the [raco](http://www.fib.upc.edu/en/serveis/raco.html). There will be a `Practica` open for each report.
#
# - Deadline: Work must be delivered __within 2 weeks__ from the end of the lab session. Late submissions risk being penalized or not accepted at all. If you anticipate problems with the deadline, tell us as soon as possible.
