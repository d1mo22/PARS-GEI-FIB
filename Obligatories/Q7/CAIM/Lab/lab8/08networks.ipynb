# %% [markdown]
# # CAIM Lab Session 8: Betweenness centrality and community detection

# %% [markdown]
# In this session you will:
#
# - familiarize yourself with the NetworkX graph library.
# - implement Brandes's algorithm for betweenness centrality.
# - implement the Girvan-Newman algorithm for community detection.
# - evaluate the community structure using a ground truth and modularity metrics.

# %% [markdown]
# # 1. NetworkX

# %% [markdown]
# Networkx is a graph library that is very convenient to use in Python.
# (Being itself written in Python, it is not the most performant one on large graphs, though.)

# %%
import networkx as nx

G = nx.Graph() 
G.add_nodes_from(range(4))
G.add_edges_from([ (0, 0), (0, 2), (0, 3), (1, 0), (1, 3), (2, 1), (2, 3), (3, 1)])

# Print degrees. Note that self-loops are counted as two edges.
for v in G.nodes():
    print("Node:", v, "Degree:", G.degree(v))

for u, v in G.edges():
    print("Edge:", u, "-", v)
    
v = 2
print("Neighbors of", v, ":", list(G.neighbors(v)))
# Out:
# Node: 0 Degree: 5
# Node: 1 Degree: 3
# Node: 2 Degree: 3
# Node: 3 Degree: 3
# Edge: 0 - 0
# Edge: 0 - 2
# Edge: 0 - 3
# Edge: 0 - 1
# Edge: 1 - 3
# Edge: 1 - 2
# Edge: 2 - 3
# Neighbors of 2 : [0, 1, 3]

# %%
import matplotlib.pyplot as plt
nx.draw(G, nx.spring_layout(G), node_size=20, edge_color="gray")

# %% [markdown]
# # 2. Betweenness centrality
# Betweenness centrality is a measure of centrality in a graph based on shortest paths.
# It may be defined for vertices and for edges.
# We will focus on edge-betweenness centrality, given by the expression
# $$
#     \text{bet}(e) = \sum_{\substack{s, t \in V \\ s \neq t}} \frac{\sigma_{st}(e)}{\sigma_{st}},
# $$
# where
#
# - $\sigma_{st} = $ number of shortest paths from $s$ to $t$
# - $\sigma_{st}(e) = $ number of shortest paths from $s$ to $t$ using edge $e$
#
# Below is a brute-force implementation to compute it on the (very small) Zachary's karate club dataset:

# %%
def normalize_edge(pair):
    return (min(pair), max(pair))    

def slow_edge_betweenness(G):
    """    
    For each ordered pair (s,t), count the fraction of shortest paths that use each edge by explicit enumeration.
    Returns a dictionary {(u,v): betweenness}.
    
    Very slow! Only for educational purposes.
    """
    bet = {normalize_edge(e): 0.0 for e in G.edges()}
    nodes = G.nodes()
    for s in nodes:
        for t in nodes:
            if s != t:                
                try:
                    paths = list(nx.all_shortest_paths(G, source=s, target=t))
                except nx.NetworkXNoPath:
                    continue
                    
                total = len(paths)
                for p in paths:                
                    for i in range(len(p) - 1):                                        
                        bet[normalize_edge((p[i], p[i + 1]))] += 1.0 / total

    return bet

# %%
G = nx.karate_club_graph()
nx.draw(G, nx.spring_layout(G), node_size=20, edge_color="gray")

# %% [markdown]
# Note that for undirected graphs, some libraries like NetworkX normalize centrality by a factor of 2 as a convention to avoid counting an edge in both directions.

# %%
bet_slow = slow_edge_betweenness(G)
bet_nx = nx.edge_betweenness_centrality(G, normalized=False)

for e in map(normalize_edge, sorted(G.edges())):
    print(e, bet_slow[e], 2 * bet_nx[e])
# Out:
# (0, 1) 28.33333333333333 28.33333333333333
# (25, 31) 47.188888888888904 47.1888888888889
# (26, 29) 5.085714285714285 5.085714285714285
# (26, 33) 60.91428571428579 60.91428571428571
# (27, 33) 34.195238095238096 34.195238095238096
# (28, 31) 16.666666666666668 16.666666666666664
# (28, 33) 27.561904761904763 27.56190476190476
# (29, 32) 26.174603174603163 26.17460317460317
# (29, 33) 33.44444444444443 33.44444444444444
# (30, 32) 19.13333333333333 19.133333333333333
# (30, 33) 30.085714285714282 30.085714285714282
# (31, 32) 46.488888888888894 46.488888888888894
# (31, 33) 59.90793650793656 59.90793650793652
# (32, 33) 9.228571428571428 9.228571428571428

# %% [markdown]
# ## Brandes's algorithm

# %% [markdown]
# The method above is rather slow, as there may be an exponential number of shortest paths between a given pair.
# Fortunately, for every fixed source vertex $s$ one may obtain the shortest path DAG and use dynamic programming to compute all $\sigma_{st}$ and $\sigma_{st}(e)$ in polynomial time.
#
# However, a naive implementation of this idea still leads to a prohibitively slow $\Omega(|V|^2 |E|)$ algorithm.
# Brandes introduced a technique to reduce the runtime by aggregating all target contributions in a single dependency pass. His algorithm computes edge and/or vertex betweenness in time $O(|V| |E|)$ and space $O(|V| + |E|)$:
#
# We start with a global array `bet[v, w]` (edge betweenness of (v, w), initialized to 0).
# Now, for every source vertex $s$, do the following:
#
# * **Step 1 – Calculation of shortest paths**
#   Perform a Breadth-First Search from $s$ to compute:
#   - `dist[v]`: shortest-path distance from $s$ to $v$.
#   - `pred[v]`: list of predecessors of node \(v\) on the shortest path DAG from the source node $s$.
#   - $\sigma[v]$: number of shortest paths from $s$ to $v$.
#
#
# * **Step 2 – Dependency accumulation**
#   Iterate through nodes in order of reverse distance from $s$ (starting from the farthest one). We need an additional array:
#   - $\delta[v]$: dependency value of node \(v\), initialized to 0.
#
#   For each predecessor $v$ of $w$, update dependency $\delta[v]$ and the total betweenness of $(v, w)$:
#
#   $$
#   \delta[v]  \gets \delta[v] + \frac{\sigma[v]}{\sigma[w]}\,\bigl(1+\delta[w]\bigr)
#   $$
#
#   and the contribution to the betweenness of edge $(v,w)$ is:
#
#   $$
#   \text{bet}(v,w) \gets \text{bet}(v, w) + \frac{\sigma[v]}{\sigma[w]} \,\bigl(1+\delta[w]\bigr).
#   $$

# %% [markdown]
# ---
#
# **Exercise 1:**
# Complete the code below to implement Brandes's algorithm. Test its accuracy and performance on the `email-Eu-core` dataset from the next section.

# %%
from collections import deque, defaultdict

def edge_betweenness(G):
    """
    Compute betweenness centrality for edges using Brandes' algorithm.
    :param G: A NetworkX graph
    :return: Dictionary of edges with betweenness centrality as the value.
    """
    bet = defaultdict(float)
    V = G.nodes()

    for s in V:
        pred = {v: [] for v in V}
        sigma = {v: 0 for v in V}
        dist = {v: -1 for v in V}
        delta = {v: 0 for v in V}

        sigma[s] = 1
        dist[s]  = 0

        queue = deque([s])
        stack = []

        # Step 1: calculate dist, sigma, pred during BFS
        while queue:
            v = queue.popleft()
            stack.append(v)
            for w in G.neighbors(v):
                if dist[w] == -1:
                    dist[w] = dist[v] + 1
                    queue.append(w)
                if dist[w] == dist[v] + 1:
                    sigma[w] += sigma[v]
                    pred[w].append(v)
            
        # Step 2: Dependency accumulation
        while stack:
            w = stack.pop()
            for v in pred[w]:
                coeff = sigma[v] / sigma[w]
                delta[v] += coeff * (1 + delta[w])
                bet[normalize_edge((v, w))] += coeff * (1 + delta[w])
            
    return bet

# %% [markdown]
# # 2. Community detection using Girvan–Newman

# %% [markdown]
# In this section we implement a well-known hierarchical method for community detection in networks: the Girvan–Newman Algorithm. It is based on the intuition that in tightly connected communities with few edges across communities, all shortest paths between vertices in different communities must go through a small set of edges, so at least one of these edges must have high  betweenness. The process is the following:
#
# * **Calculate Edge Betweenness**  for every edge.
#
# * **Edge Removal**: iteratively remove the edge with the highest betweenness centrality until some component becomes disconnected. At this point, we obtained a finer partition.
#
# * **Community Detection**
#   Continue the steps above until all nodes are isolated.
#
# This process results in a sequence of partitions. Typically we use **modularity** to select the single best partition;  higher modularity typically indicates a better community structure.
# We only record modularity and partitions when the number of connected components increases (i.e., the partition changes). Modularity is computed using the original graph.
#
#   A formula to quickly compute the modularity $Q$ of a partition is
#   $$ Q = \sum_{C} \left[ \frac{m_C}{m} - \left( \frac{K_C}{2m} \right)^2 \right] $$
#
# where
#  * $m_C$ is the number of edges within community $C$,
#  * $K_C$ = sum of degrees of all nodes *in* $C$, and
#  * $m$ is the total number of edges.
#
#  The trivial partition into one cluster always have modularity 0 and typically we don't need to record it.

# %% [markdown]
# ## Dataset

# %% [markdown]
# We will use the email-Eu-core network from SNAP, a graph with 42 ground-truth clusters. We treat it as undirected and remove loops.
#
# https://snap.stanford.edu/data/email-Eu-core.html

# %%
#!wget https://snap.stanford.edu/data/email-Eu-core.txt.gz && gunzip email-Eu-core.txt.gz
#!wget https://snap.stanford.edu/data/email-Eu-core-department-labels.txt.gz && gunzip email-Eu-core-department-labels.txt.gz

# %%
G = nx.read_edgelist("email-Eu-core.txt", nodetype=int)
G.remove_edges_from(nx.selfloop_edges(G))
print("Loaded graph:", G.number_of_nodes(), "nodes,", G.number_of_edges(), "edges")
# Out:
# Loaded graph: 1005 nodes, 16064 edges

# %% [markdown]
# Load the ground truth labels

# %%
def compute_modularity(G_original, components):
    """
    Compute modularity for a partition (components) with respect to G_original.
    """
    m = G_original.number_of_edges()
    if m == 0: return 0

    Q = 0.0
    for C in components:
        subgraph = G_original.subgraph(C)
        m_C = subgraph.number_of_edges()
        K_C = sum(G_original.degree(v) for v in C)
        Q += (m_C / m) - (K_C / (2 * m)) ** 2
    return Q

# %%
with open("email-Eu-core-department-labels.txt") as f:
    ground_truth = dict([tuple(map(int, l.split())) for l in f.readlines()])
ground_communities = defaultdict(list)
for v, cluster_id in ground_truth.items():
    ground_communities[cluster_id].append(v)
print(len(ground_communities), "communities")    
print("Ground truth cluster sizes =", sorted([len(C) for C in ground_communities.values()], key = lambda x:-x))
print("Ground truth modularity =", compute_modularity(G, ground_communities.values()))
# Out:
# 42 communities
# Ground truth cluster sizes = [109, 92, 65, 61, 55, 51, 49, 39, 35, 32, 29, 29, 28, 27, 26, 25, 25, 22, 19, 18, 15, 14, 13, 13, 13, 12, 10, 10, 9, 9, 8, 8, 6, 6, 5, 4, 4, 3, 3, 2, 1, 1]
# Ground truth modularity = 0.28801318862374214

# %% [markdown]
# Running Girvan-Newman on the full graph component is too slow in Python, so to speed up computations we sample a smaller connected subgraph that still preserves meaningful community structure.
# In order to do so, we perform a certain kind of random walk of limited size that attempts to avoid repeating vertices, and consider only the subgraph induced by those nodes.

# %%
import numpy as np

def random_walk_sample(G, size, start=None):
    if start is None:
        start = np.random.choice(list(G.nodes()))
    sample = {start}
    current = start
    size = min(size, G.number_of_nodes())
    while len(sample) < size:
        neighbors = list(set(G.neighbors(current)) - sample)
        if not neighbors:
            current = np.random.choice(list(set(G.nodes()) - sample))
        else:
            current = np.random.choice(neighbors)
        sample.add(current)
    return sample

np.random.seed(4123814)
node_subset = random_walk_sample(G, size=250)
smallG = G.subgraph(node_subset).copy()
print("Induced subgraph:", smallG.number_of_nodes(), "nodes,", smallG.number_of_edges(), "edges")
smallG = G.subgraph(max(nx.connected_components(smallG), key=len)).copy()
assert len(list(nx.connected_components(smallG))) == 1
# Out:
# Induced subgraph: 250 nodes, 3523 edges

# %%
induced_ground_communities = defaultdict(list)
for v in smallG.nodes():
    induced_ground_communities[ground_truth[v]].append(v)
print("SmallG:", len(induced_ground_communities), "communities")    
print("Ground truth cluster sizes =", sorted([len(C) for C in induced_ground_communities.values()], key = lambda x:-x))
print("Ground truth modularity =", compute_modularity(smallG, induced_ground_communities.values()))
# Out:
# SmallG: 34 communities
# Ground truth cluster sizes = [26, 22, 20, 18, 15, 13, 12, 12, 11, 11, 9, 7, 6, 6, 6, 6, 5, 5, 4, 4, 4, 4, 3, 3, 3, 3, 2, 2, 2, 2, 1, 1, 1, 1]
# Ground truth modularity = 0.1923686437021579

# %% [markdown]
# Este es un test para provar que el algoritmo implementado Brandes funciona correctamente y de manera eficiente.

# %%
G_test = nx.karate_club_graph()
bet_brandes = edge_betweenness(G_test)
bet_slow = slow_edge_betweenness(G_test)

for e in map(normalize_edge, sorted(G_test.edges())):
    print(e, bet_brandes[e], bet_slow[e])
# Out:
# (0, 1) 28.33333333333333 28.33333333333333
# (0, 2) 87.27777777777777 87.27777777777781
# (0, 3) 23.0 23.0
# (0, 4) 58.666666666666664 58.666666666666806
# (0, 5) 87.66666666666666 87.66666666666647
# (0, 6) 87.66666666666667 87.66666666666649
# (0, 7) 25.6047619047619 25.604761904761915
# (0, 8) 83.29682539682543 83.29682539682558
# (0, 10) 58.666666666666664 58.66666666666683
# (0, 11) 66.0 66.00000000000021
# (0, 12) 52.199999999999996 52.200000000000166
# (0, 13) 47.54126984126986 47.54126984127002
# (0, 17) 45.019047619047626 45.019047619047754
# (0, 19) 51.54126984126985 51.54126984126998
# (0, 21) 45.01904761904762 45.01904761904775
# (0, 31) 142.78571428571428 142.78571428571405
# (1, 2) 26.06666666666667 26.06666666666665
# (1, 3) 8.666666666666666 8.666666666666666
# %% [markdown]
# ---
#
# **Exercise 2:**
# Complete the code below to implement the Girvan-Newman algorithm and test in on `smallG`. Then:
# - Track the modularity score at each iteration. How does it evolve as the algorithm progresses?
# - Compare the Girvan-Newman algorithm with the Louvain algorithm (available in NetworkX) on the same dataset. Which one returns a higher-modularity clustering on this dataset?
# - Compare the clusterings found by Girvan-Newman and Louvain with the ground truth and with via metrics such as number of clusters, precision/recall in terms of vertex pairs, and/or Adjusted Rand Index. (You may use, e.g., `adjusted_rand_score` from `sklearn.metrics`.)

# %%
from sklearn.metrics import adjusted_rand_score

def girvan_newman(G):
    """
    Implementation of the full Girvan-Newman Algorithm for community detection.    
    Returns:
        partitions: list of component lists
        modularities: list of modularity values
    """
    G0 = G.copy()
    G = G.copy()    
    partitions = []
    modularities = []

    while G.number_of_edges() > 0:
        # Remove edge with the highest betweenness centrality
        from networkx.algorithms.centrality import edge_betweenness_centrality
        bet = edge_betweenness_centrality(G)
        e = max(bet.items(), key=lambda x: x[1])[0]
        G.remove_edge(*e)
        
        # Get connected components (current set of communities)
        comps = list(nx.connected_components(G))
        
        # If the partition has changed, add it and its modularity score (w.r.t to the original graph)
        if not partitions or set(map(frozenset, comps)) != set(map(frozenset, partitions[-1])):
            partitions.append(comps)
            modularities.append(compute_modularity(G0, comps))

    return partitions, modularities

# %%
# Run Girvan-Newman on smallG
partitions, modularities = girvan_newman(smallG)

# Run Louvain on smallG
louvain_communities = list(nx.community.louvain_communities(smallG))
louvain_modularity = compute_modularity(smallG, louvain_communities)

# %%
# Track modularity evolution
print("Girvan-Newman Modularity Evolution:")
for i, mod in enumerate(modularities):
    print(f"Iteration {i+1}: Modularity = {mod:.4f}")

print("Final Girvan-Newman Modularity: {:.4f}".format(modularities[-1] if modularities else 0))
print(f"\nLouvain Modularity: {louvain_modularity:.4f}")

# Compare which has higher modularity
if modularities and louvain_modularity > max(modularities):
    print("Louvain has higher modularity.")
elif modularities and louvain_modularity < max(modularities):
    print("Girvan-Newman has higher modularity.")
else:
    print("Modularities are comparable.")

if partitions:
    best_gn_partition = partitions[modularities.index(max(modularities))]
    gn_labels = [0] * smallG.number_of_nodes()
    for idx, comm in enumerate(best_gn_partition):
        for node in comm:
            gn_labels[list(smallG.nodes()).index(node)] = idx
else:
    best_gn_partition = []
    gn_labels = []

nodes = list(smallG.nodes())
node_index = {node: i for i, node in enumerate(nodes)}
n = len(nodes)


gn_labels = [-1] * n
for cid, comm in enumerate(best_gn_partition):
    for node in comm:
        gn_labels[node_index[node]] = cid

# For Louvain
lv_labels = [-1] * n
for cid, comm in enumerate(louvain_communities):
    for node in comm:
        lv_labels[node_index[node]] = cid

# Ground truth labels
gt_labels = [ground_truth[node] for node in nodes]

# Number of clusters
print(f"Girvan-Newman Clusters: {len(partitions[-1]) if partitions else 0}")
print(f"Girvan-Newman Best Clusters: {len(best_gn_partition)}")
print(f"Louvain Clusters: {len(louvain_communities)}")


lv_labels = [-1] * n
for cid, comm in enumerate(louvain_communities):
    for node in comm:
        lv_labels[node_index[node]] = cid

gt_labels = [ground_truth[node] for node in nodes]
assert all(l != -1 for l in gn_labels), "Error: GN dejó nodos sin etiquetar"
assert all(l != -1 for l in lv_labels), "Error: Louvain dejó nodos sin etiquetar"



print("Girvan-Newman ARI:", adjusted_rand_score(gt_labels, gn_labels))
print("Louvain ARI:", adjusted_rand_score(gt_labels, lv_labels))


# Precision/Recall for vertex pairs (simplified: fraction of pairs in same cluster that are correct)
# This is a basic implementation; for full pairwise, it's expensive
def pair_accuracy(true_comms, pred_comms, graph):
    true_pairs = set()
    for comm in true_comms:
        comm = list(comm)
        for i in range(len(comm)):
            for j in range(i+1, len(comm)):
                true_pairs.add((min(comm[i], comm[j]), max(comm[i], comm[j])))
    
    pred_pairs = set()
    for comm in pred_comms:
        comm = list(comm)
        for i in range(len(comm)):
            for j in range(i+1, len(comm)):
                pred_pairs.add((min(comm[i], comm[j]), max(comm[i], comm[j])))
    
    correct = len(true_pairs & pred_pairs)
    total_pred = len(pred_pairs)
    total_true = len(true_pairs)
    precision = correct / total_pred if total_pred > 0 else 0
    recall = correct / total_true if total_true > 0 else 0
    return precision, recall

if best_gn_partition:
    gn_prec, gn_rec = pair_accuracy(induced_ground_communities.values(), best_gn_partition, smallG)
    print(f"Girvan-Newman Pair Precision: {gn_prec:.4f}, Recall: {gn_rec:.4f}")

lv_prec, lv_rec = pair_accuracy(induced_ground_communities.values(), louvain_communities, smallG)
print(f"Louvain Pair Precision: {lv_prec:.4f}, Recall: {lv_rec:.4f}")
# Out:
# Girvan-Newman Modularity Evolution:
# Iteration 1: Modularity = -0.0000
# Iteration 2: Modularity = -0.0000
# Iteration 3: Modularity = -0.0000
# Iteration 4: Modularity = -0.0000
# Iteration 5: Modularity = -0.0000
# Iteration 6: Modularity = -0.0000
# Iteration 7: Modularity = -0.0000
# Iteration 8: Modularity = -0.0000
# Iteration 9: Modularity = -0.0000
# Iteration 10: Modularity = -0.0000
# Iteration 11: Modularity = -0.0000
# Iteration 12: Modularity = 0.0134
# Iteration 13: Modularity = 0.0134
# Iteration 14: Modularity = 0.0134
# Iteration 15: Modularity = 0.0133
# Iteration 16: Modularity = 0.0133
# Iteration 17: Modularity = 0.0136
# Iteration 18: Modularity = 0.0135
# Iteration 19: Modularity = 0.0143
# Iteration 20: Modularity = 0.0143
# Iteration 21: Modularity = 0.0142
# Iteration 22: Modularity = 0.0142
# Iteration 23: Modularity = 0.0141
# Iteration 24: Modularity = 0.0143
# Iteration 25: Modularity = 0.0143
# Iteration 26: Modularity = 0.0145
# Iteration 27: Modularity = 0.0147
# Iteration 28: Modularity = 0.0147
# Iteration 29: Modularity = 0.0148
# Iteration 30: Modularity = 0.0150
# Iteration 31: Modularity = 0.0152
# Iteration 32: Modularity = 0.0172
# Iteration 33: Modularity = 0.0171
# Iteration 34: Modularity = 0.0175
# Iteration 35: Modularity = 0.0177
# Iteration 36: Modularity = 0.0178
# Iteration 37: Modularity = 0.0188
# Iteration 198: Modularity = 0.0433
# Iteration 199: Modularity = 0.0418
# Iteration 200: Modularity = 0.0406
# Iteration 201: Modularity = 0.0395
# Iteration 202: Modularity = 0.0367
# Iteration 203: Modularity = 0.0344
# Iteration 204: Modularity = 0.0337
# Iteration 205: Modularity = 0.0346
# Iteration 206: Modularity = 0.0333
# Iteration 207: Modularity = 0.0308
# Iteration 208: Modularity = 0.0290
# Iteration 209: Modularity = 0.0278
# Iteration 210: Modularity = 0.0277
# Iteration 211: Modularity = 0.0266
# Iteration 212: Modularity = 0.0267
# Iteration 213: Modularity = 0.0244
# Iteration 214: Modularity = 0.0231
# Iteration 215: Modularity = 0.0239
# Iteration 216: Modularity = 0.0226
# Iteration 217: Modularity = 0.0206
# Iteration 218: Modularity = 0.0206
# Iteration 219: Modularity = 0.0192
# Iteration 220: Modularity = 0.0183
# Iteration 221: Modularity = 0.0170
# Iteration 222: Modularity = 0.0182
# Iteration 223: Modularity = 0.0169
# Iteration 224: Modularity = 0.0155
# Iteration 225: Modularity = 0.0133
# Iteration 226: Modularity = 0.0113
# Iteration 227: Modularity = 0.0099
# Iteration 228: Modularity = 0.0081
# Iteration 229: Modularity = 0.0066
# Iteration 230: Modularity = 0.0055
# Iteration 231: Modularity = 0.0051
# Iteration 232: Modularity = 0.0042
# Iteration 233: Modularity = 0.0029
# Iteration 234: Modularity = 0.0019
# Iteration 235: Modularity = 0.0014
# Iteration 236: Modularity = 0.0003
# Iteration 237: Modularity = -0.0005
# Iteration 238: Modularity = -0.0014
# Iteration 239: Modularity = -0.0019
# Iteration 240: Modularity = -0.0022
# Iteration 241: Modularity = -0.0030
# Iteration 242: Modularity = -0.0036
# Iteration 243: Modularity = -0.0043
# Iteration 244: Modularity = -0.0045
# Iteration 245: Modularity = -0.0050
# Iteration 246: Modularity = -0.0056
# Iteration 247: Modularity = -0.0058
# Iteration 248: Modularity = -0.0060
# Iteration 249: Modularity = -0.0061
# Final Girvan-Newman Modularity: -0.0061
#
# Louvain Modularity: 0.3206
# Louvain has higher modularity.
# Girvan-Newman Clusters: 250
# Girvan-Newman Best Clusters: 145
# Louvain Clusters: 7
# Girvan-Newman ARI: 0.03805270366813931
# Louvain ARI: 0.3164737378814632
# Girvan-Newman Pair Precision: 0.0730, Recall: 0.1825
# Louvain Pair Precision: 0.2379, Recall: 0.8055
# /home/david/anaconda3/envs/CAIM/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:50: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(labels_pred)

# %% [markdown]
# ## Informe: Soluciones y Conclusiones
#
# ### Ejercicio 1: Algoritmo de Brandes para Betweenness de Aristas
#
# **Detalles de Implementación:**
#
# El algoritmo utiliza las siguientes estructuras de datos:
# - `deque` para la cola BFS (operaciones O(1) en append/popleft)
# - `stack` (lista) para procesar nodos en orden inverso
# - Diccionarios para `dist`, `sigma`, `pred`, `delta` indexados por nodo
# - `defaultdict(float)` para acumular los valores de betweenness
#
# **Pasos del Algoritmo:**
# 1. **Fase BFS**: Para cada nodo fuente $s$, calcular distancias de camino más corto (`dist`), número de caminos más cortos (`sigma`), y predecesores en el DAG de caminos más cortos (`pred`)
# 2. **Fase de Acumulación**: Procesar nodos en orden inverso al BFS (usando stack), calculando dependencias $\delta[v]$ y actualizando el betweenness de aristas usando: $\frac{\sigma[v]}{\sigma[w]} \cdot (1 + \delta[w])$
#
# **Validación**: La implementación fue validada contra `slow_edge_betweenness` en el grafo Karate Club. Ambos métodos producen resultados idénticos, confirmando la corrección.
#
# **Complejidad**: $O(|V| \cdot |E|)$ tiempo, $O(|V| + |E|)$ espacio
#
# ---
#
# ### Ejercicio 2: Algoritmo de Girvan-Newman
#
# **Detalles de Implementación:**
# - Mantiene una copia de trabajo del grafo para eliminar aristas
# - Conserva referencia al grafo original para calcular modularidad
# - Usa `edge_betweenness_centrality` de NetworkX por eficiencia
# - Registra particiones solo cuando cambia el número de componentes conexas
#
# **Resultados en smallG (250 nodos, ~3500 aristas):**
#
# | Métrica | Girvan-Newman | Louvain | Ground Truth |
# |---------|---------------|---------|--------------|
# | **Modularidad** | 0.0808 (máx) | **0.3206** | 0.192 |
# | **Clusters** | 145 | **7** | 34 |
# | **ARI** | 0.038 | **0.316** | - |
# | **Precisión** | 0.073 | **0.238** | - |
# | **Recall** | 0.183 | **0.806** | - |
#
# **Evolución de la Modularidad:**
# - Empieza cerca de 0 (un solo cluster)
# - Aumenta gradualmente conforme se dividen las comunidades
# - Alcanza el máximo (~0.08) alrededor de la iteración 144
# - Disminuye debido a la sobre-fragmentación
#
# ---
#
# ### Conclusiones
#
# 1. **Louvain supera significativamente a Girvan-Newman** en este dataset en todas las métricas (modularidad, ARI, precisión, recall)
#
# 2. **GN tiende a sobre-fragmentar** grafos densos: 145 clusters para 250 nodos es excesivo. Esto ocurre porque en grafos densos, el betweenness está más uniformemente distribuido entre las aristas.
#
# 3. **Ground truth ≠ óptimo topológico**: El ground truth (departamentos) tiene modularidad 0.19, mientras que Louvain alcanza 0.32. La estructura organizacional real no coincide perfectamente con los patrones de comunicación.
#
# 4. **Compromisos:**
#    - GN: Jerárquico, interpretable, pero lento y fragmenta grafos densos
#    - Louvain: Rápido, alta modularidad, pero greedy y no determinista
#
# ---

# %% [markdown]
# ## 5. Rules of delivery
#
# - To be solved in _pairs_.
#
# - Submit the **report** as a PDF file. Make sure it has **both your names, date, and title**. Include your **code** in your submission (.py or .ipynb).
#
# - No plagiarism; don't discuss your work with other teams. You can ask for help to others for simple things, such as recalling a python instruction or module, but nothing too specific to the session.
#
# - If you feel you are spending much more time than the rest of the classmates, ask us for help. Questions can be asked either in person or by email, and you'll never be penalized by asking questions, no matter how stupid they look in retrospect.
#
# - Write a short report listing the solutions to the exercises proposed. Include things like the important parts of your implementation (data structures used for representing objects, algorithms used, etc). You are welcome to add conclusions and findings that depart from what we asked you to do. We encourage you to discuss the difficulties you find; this lets us give you help and also improve the lab session for future editions.
#
#
#
# - Submit your work through the [raco](http://www.fib.upc.edu/en/serveis/raco.html); see date at the raco's submissions page.
